# %% [markdown]
# # Descripción:
#
# Análisis de datos, ingeniería de variables, y modelamiento a través de Pycaret

# %%
import os
os.chdir('C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto')

# %%
u=!pip freeze
instalados=str(u)

# %%
to_instalar=['os','pandas','matplotlib','statsmodels','numpy','seaborn','pingouin','pycaret','sklearn','scipy','openpyxl','optuna',
            'xgboost','sns']

# %%
instalados=[x for x in to_instalar if x in  instalados ]
if len(set(to_instalar)-set(instalados))>0:
    # !pip install -r requirements_pycaret.txt
# Out:
# Requirement already satisfied: pandas in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 1)) (1.3.5)
# Requirement already satisfied: scipy<=1.5.4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 2)) (1.5.4)
# Requirement already satisfied: seaborn in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 3)) (0.11.2)
# Requirement already satisfied: matplotlib in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 4)) (3.5.2)
# Requirement already satisfied: IPython in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 5)) (7.34.0)
# Requirement already satisfied: joblib in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 6)) (1.1.0)
# Requirement already satisfied: scikit-learn==0.23.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 7)) (0.23.2)
# Requirement already satisfied: ipywidgets in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 8)) (7.7.1)
# Requirement already satisfied: yellowbrick>=1.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 9)) (1.3.post1)
# Requirement already satisfied: lightgbm>=2.3.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 10)) (3.3.2)
# Requirement already satisfied: plotly>=4.4.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 11)) (5.9.0)
# Requirement already satisfied: wordcloud in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 12)) (1.8.1)
# Requirement already satisfied: textblob in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 13)) (0.17.1)
# Requirement already satisfied: cufflinks>=0.17.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 14)) (0.17.3)
# Requirement already satisfied: umap-learn in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 15)) (0.5.3)
# Requirement already satisfied: pyLDAvis in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 16)) (3.2.2)
# Requirement already satisfied: gensim<4.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 17)) (3.8.3)
# Requirement already satisfied: spacy<2.4.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 18)) (2.3.7)
# Requirement already satisfied: nltk in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 19)) (3.7)
# Requirement already satisfied: mlxtend>=0.17.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 20)) (0.19.0)
# Requirement already satisfied: pyod in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 21)) (1.0.2)
# Requirement already satisfied: pandas-profiling>=2.8.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 22)) (3.2.0)
# Requirement already satisfied: kmodes>=0.10.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 23)) (0.12.1)
# Requirement already satisfied: mlflow in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 24)) (1.26.1)
# Requirement already satisfied: imbalanced-learn==0.7.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 25)) (0.7.0)
# Requirement already satisfied: scikit-plot in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 26)) (0.3.7)
# Requirement already satisfied: Boruta in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 27)) (0.3)
# Requirement already satisfied: pyyaml<6.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 28)) (5.4.1)
# Requirement already satisfied: numba<0.55 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 29)) (0.54.1)
# Requirement already satisfied: pycaret in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 30)) (2.3.10)
# Requirement already satisfied: sklearn in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 31)) (0.0)
# Requirement already satisfied: pingouin in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 32)) (0.3.12)
# Requirement already satisfied: statsmodels in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 33)) (0.13.2)
# Requirement already satisfied: openpyxl in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 34)) (3.0.10)
# Requirement already satisfied: optuna in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 35)) (2.10.1)
# Requirement already satisfied: xgboost in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 36)) (1.6.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from scikit-learn==0.23.2->-r requirements_pycaret.txt (line 7)) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from scikit-learn==0.23.2->-r requirements_pycaret.txt (line 7)) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas->-r requirements_pycaret.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas->-r requirements_pycaret.txt (line 1)) (2022.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (9.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (3.0.9)
# Requirement already satisfied: colorama in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.4.5)
# Requirement already satisfied: decorator in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.1.3)
# Requirement already satisfied: traitlets>=4.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (5.3.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (47.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.18.1)
# Requirement already satisfied: pygments in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (2.12.0)
# Requirement already satisfied: pickleshare in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.7.5)
# Requirement already satisfied: backcall in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (3.0.29)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipywidgets->-r requirements_pycaret.txt (line 8)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipywidgets->-r requirements_pycaret.txt (line 8)) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipywidgets->-r requirements_pycaret.txt (line 8)) (6.15.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipywidgets->-r requirements_pycaret.txt (line 8)) (1.1.1)
# Requirement already satisfied: wheel in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from lightgbm>=2.3.1->-r requirements_pycaret.txt (line 10)) (0.37.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from plotly>=4.4.1->-r requirements_pycaret.txt (line 11)) (8.0.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cufflinks>=0.17.0->-r requirements_pycaret.txt (line 14)) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cufflinks>=0.17.0->-r requirements_pycaret.txt (line 14)) (0.3.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from umap-learn->-r requirements_pycaret.txt (line 15)) (0.5.7)
# Requirement already satisfied: tqdm in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from umap-learn->-r requirements_pycaret.txt (line 15)) (4.64.0)
# Requirement already satisfied: jinja2>=2.7.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pyLDAvis->-r requirements_pycaret.txt (line 16)) (3.1.2)
# Requirement already satisfied: numexpr in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pyLDAvis->-r requirements_pycaret.txt (line 16)) (2.8.1)
# Requirement already satisfied: future in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pyLDAvis->-r requirements_pycaret.txt (line 16)) (0.18.2)
# Requirement already satisfied: funcy in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pyLDAvis->-r requirements_pycaret.txt (line 16)) (1.17)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gensim<4.0.0->-r requirements_pycaret.txt (line 17)) (6.0.0)
# Requirement already satisfied: Cython==0.29.14 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gensim<4.0.0->-r requirements_pycaret.txt (line 17)) (0.29.14)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (0.9.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (0.7.8)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (3.0.6)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (7.4.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (2.28.0)
# Requirement already satisfied: click in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nltk->-r requirements_pycaret.txt (line 19)) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nltk->-r requirements_pycaret.txt (line 19)) (2022.6.2)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.7.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.2.0)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.5.1)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (2.1.1)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.1.12)
# Requirement already satisfied: phik>=0.11.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.12.2)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (1.9.1)
# Requirement already satisfied: multimethod>=1.4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (1.8)
# Requirement already satisfied: networkx>=2.4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (21.4.0)
# Requirement already satisfied: imagehash in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (4.2.1)
# Requirement already satisfied: entrypoints in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (0.4)
# Requirement already satisfied: sqlalchemy in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (1.4.38)
# Requirement already satisfied: databricks-cli>=0.8.7 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (0.17.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (3.20.1)
# Requirement already satisfied: alembic in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (1.8.0)
# Requirement already satisfied: querystring-parser in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (1.2.4)
# Requirement already satisfied: Flask in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (2.1.2)
# Requirement already satisfied: waitress in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (2.1.2)
# Requirement already satisfied: docker>=4.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (5.0.3)
# Requirement already satisfied: prometheus-flask-exporter in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (0.20.2)
# Requirement already satisfied: sqlparse>=0.3.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (0.4.2)
# Requirement already satisfied: gitpython>=2.1.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (3.1.27)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (4.11.4)
# Requirement already satisfied: cloudpickle in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (2.1.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from numba<0.55->-r requirements_pycaret.txt (line 29)) (0.37.0)
# Requirement already satisfied: pandas-flavor>=0.1.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pingouin->-r requirements_pycaret.txt (line 32)) (0.2.0)
# Requirement already satisfied: outdated in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pingouin->-r requirements_pycaret.txt (line 32)) (0.2.1)
# Requirement already satisfied: tabulate in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pingouin->-r requirements_pycaret.txt (line 32)) (0.8.10)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from statsmodels->-r requirements_pycaret.txt (line 33)) (0.5.2)
# Requirement already satisfied: et-xmlfile in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from openpyxl->-r requirements_pycaret.txt (line 34)) (1.1.0)
# Requirement already satisfied: cmaes>=0.8.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from optuna->-r requirements_pycaret.txt (line 35)) (0.8.2)
# Requirement already satisfied: colorlog in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from optuna->-r requirements_pycaret.txt (line 35)) (6.6.0)
# Requirement already satisfied: cliff in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from optuna->-r requirements_pycaret.txt (line 35)) (3.10.1)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from databricks-cli>=0.8.7->mlflow->-r requirements_pycaret.txt (line 24)) (2.4.0)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from databricks-cli>=0.8.7->mlflow->-r requirements_pycaret.txt (line 24)) (3.2.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from docker>=4.0.0->mlflow->-r requirements_pycaret.txt (line 24)) (1.3.3)
# Requirement already satisfied: pywin32==227 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from docker>=4.0.0->mlflow->-r requirements_pycaret.txt (line 24)) (227)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gitpython>=2.1.0->mlflow->-r requirements_pycaret.txt (line 24)) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gitpython>=2.1.0->mlflow->-r requirements_pycaret.txt (line 24)) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->-r requirements_pycaret.txt (line 24)) (3.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.5.5)
# Requirement already satisfied: psutil in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from jedi>=0.16->IPython->-r requirements_pycaret.txt (line 5)) (0.8.3)
# Requirement already satisfied: xarray in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-flavor>=0.1.2->pingouin->-r requirements_pycaret.txt (line 32)) (0.20.2)
# Requirement already satisfied: wcwidth in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->-r requirements_pycaret.txt (line 5)) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (3.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from sqlalchemy->mlflow->-r requirements_pycaret.txt (line 24)) (1.1.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (6.4.12)
# Requirement already satisfied: importlib-resources in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from alembic->mlflow->-r requirements_pycaret.txt (line 24)) (5.8.0)
# Requirement already satisfied: Mako in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from alembic->mlflow->-r requirements_pycaret.txt (line 24)) (1.2.0)
# Requirement already satisfied: stevedore>=2.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cliff->optuna->-r requirements_pycaret.txt (line 35)) (3.5.0)
# Requirement already satisfied: autopage>=0.4.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cliff->optuna->-r requirements_pycaret.txt (line 35)) (0.5.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cliff->optuna->-r requirements_pycaret.txt (line 35)) (5.9.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cliff->optuna->-r requirements_pycaret.txt (line 35)) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cliff->optuna->-r requirements_pycaret.txt (line 35)) (2.4.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from Flask->mlflow->-r requirements_pycaret.txt (line 24)) (2.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from Flask->mlflow->-r requirements_pycaret.txt (line 24)) (2.1.2)
# Requirement already satisfied: littleutils in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from outdated->pingouin->-r requirements_pycaret.txt (line 32)) (0.2.2)
# Requirement already satisfied: prometheus-client in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from prometheus-flask-exporter->mlflow->-r requirements_pycaret.txt (line 24)) (0.14.1)
# Requirement already satisfied: pyreadline3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cmd2>=1.0.0->cliff->optuna->-r requirements_pycaret.txt (line 35)) (3.4.1)
# Requirement already satisfied: pyperclip>=1.6 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cmd2>=1.0.0->cliff->optuna->-r requirements_pycaret.txt (line 35)) (1.8.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->-r requirements_pycaret.txt (line 24)) (5.0.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (4.10.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (6.5.0)
# Requirement already satisfied: nbformat in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (5.4.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.15.0)
# Requirement already satisfied: PyWavelets in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (1.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.6.4)
# Requirement already satisfied: bleach in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (5.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.2.2)
# Requirement already satisfied: defusedxml in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.7.1)
# Requirement already satisfied: tinycss2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (4.11.1)
# Requirement already satisfied: fastjsonschema in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (4.6.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.18.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (2.21)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages)

# %%
import pycaret

# %%
import optuna

# %%
#!pip install -r requirements.txt --user
import os
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
import seaborn as sns
from datetime import datetime
import math
import unicodedata
from unicodedata import normalize
import re
from dateutil.relativedelta import relativedelta
import pingouin
import sklearn
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import scipy
from scipy.stats import chi2_contingency
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as smf
#import tune_sklearn
#import pycaret

# %%
ruta_madre="C:/Users/USUARIO/Documents/GitHub/Team_224/Proyecto"
ruta_insumos=os.path.join(ruta_madre, 'Insumos')
ruta_resultados=os.path.join(ruta_madre, 'Resultados')
# Out:
# c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.12, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %% [markdown]
# ## 1.0 Importando base de datos preprocesada
#
# Tomamos la data proveniente del EDA y la usamos para nuestro ejercicio de modelaje

# %%
os.chdir(os.path.join(ruta_insumos,'preproccess_data'))
ruta_data_preproc=os.path.join(os.getcwd(),'data_agregada_preproccess.xlsx')
datos_preproc=pd.read_excel(ruta_data_preproc,index_col=0)

# %% [markdown]
# ## 2.0 Featuring engineering
#
# Se empiza a hacer Feature engineering para evitar resultados raros en el modelaje y mejorar el desempeño del mismo

# %% [markdown]
# ### 2.1 Deflactando los salarios
#
# Debido al gran problema que genera la inflación a lo largo del tiempo, se prefiere usar cifras deflactadas, con lo cual, se utiliza la tabal abstraida del DANE para el IPC anual y se indexa hasta valores correspondientes al 2022. Es decir, la serie se deflacta y se pone todo en las mismas unidades monetarias en el mismo intervalo de tiempo

# %%
inflacion_variacion=pd.read_excel(os.path.join(os.getcwd(),'inflacion.xlsx'),index_col=0)
inflacion_variacion['inflacion']=inflacion_variacion['inflacion']/100+1
inflacion_variacion=inflacion_variacion[inflacion_variacion.index>=datos_preproc.year.min()]

# %%
inflacion_variacion=inflacion_variacion.sort_index(ascending=False).cumprod().reset_index()

# %%
datos_preproc=datos_preproc.merge(inflacion_variacion,on="year",how="left")
datos_preproc.inflacion.fillna(1,inplace=True)

# %%
datos_preproc['wage_deflacted']=datos_preproc['wage_imputed']*datos_preproc['inflacion']

# %% [markdown]
# ### 2.2 Arreglando variables categoricas incompletas
#
# Algunas variables sufren de datos faltantes dificiles de imputar y de High Cardinality que puede afectar el balanceo de las variables explicativas. Para ello, se agrupan algunas categorias con el fin de solventar estos datos atípicos

# %%
datos_preproc['total_depedants']=datos_preproc['other_on_charge_person']+datos_preproc['children_amount']

# %%
datos_to_model=datos_preproc[['month','gender','is_special_population','any_disability','MUNICIPIO_DE_RESIDENCIA','home_type',
                             'education_level','PROFESION','marital_status','total_depedants','ESTRATO_SOCIAL','wage_deflacted',
                             'age','years_exp_current_role','request_attend_per_day']].copy()
datos_to_model['total_depedants']=datos_to_model['total_depedants'].astype('str')
datos_to_model['ESTRATO_SOCIAL']=datos_to_model['ESTRATO_SOCIAL'].astype('str')

# %%
datos_to_model.isna().sum().to_frame()
# Out:
#                           0
# month                     0
# gender                    3
# is_special_population     3
# any_disability            3
# MUNICIPIO_DE_RESIDENCIA   3
# home_type                 3
# education_level           3
# PROFESION                65
# marital_status            3
# total_depedants           0
# ESTRATO_SOCIAL            0
# wage_deflacted            0
# age                       3
# years_exp_current_role    3
# request_attend_per_day    0

# %% [markdown]
# Note que hay un total importante de `NAs` en algunos datos. sin embargo, no tenemos ninguna explicación de negocio para reemplazarlos por un numero, por lo que se pondrá como una nueva categoria

# %%
datos_to_model['gender']=datos_to_model['gender'].fillna('OTHER')
datos_to_model['is_special_population']=datos_to_model['is_special_population'].fillna('NO APLICA')
datos_to_model['any_disability']=datos_to_model['any_disability'].fillna('no_reported')
datos_to_model['MUNICIPIO_DE_RESIDENCIA']=datos_to_model['MUNICIPIO_DE_RESIDENCIA'].fillna('NO_REPORTADO')
datos_to_model['home_type']=datos_to_model['home_type'].fillna('OTHER')
datos_to_model['education_level']=datos_to_model['education_level'].fillna('OTHER')
datos_to_model['PROFESION']=datos_to_model['PROFESION'].fillna('OTHER')
datos_to_model['marital_status']=datos_to_model['marital_status'].fillna('OTHER')
datos_to_model['total_depedants']=datos_to_model['total_depedants'].fillna('OTHER')
datos_to_model['ESTRATO_SOCIAL']=datos_to_model['ESTRATO_SOCIAL'].fillna('OTHER')

# %% [markdown]
# El siguiente código presenta una transformacion de la variable edad, ya que al verlo respecto a la variable que mide la productividad, tiene una relacion no lineal.

# %% [markdown]
# ### 2.3 Agregando polinomios de la edad
#
# Como se vió en el EDA, la edad tiene ua relación no lineal ni cuadrática con respecto a la variable `request_attend_per_day`

# %%
datos_to_model['age2']=datos_to_model['age']**2
datos_to_model['age3']=datos_to_model['age']**3
datos_to_model['age4']=datos_to_model['age']**4
datos_to_model['age5']=datos_to_model['age']**5

# %% [markdown]
# ## 3.0 Modelo de referencia de Regresión lineal (baseline model)

# %% [markdown]
# ### 3.1 Dividiendo en test y train set

# %% [markdown]
# Utilzamos un split de 70/30, sin embargo, solo usaremos este ejercicio con fin de tener una referencia de potenciales variables significativas. siendo el peor modelo y luego ir viendo como se comporta a futuro con modelos más sofisticados

# %%
y=datos_to_model[datos_to_model.columns[datos_to_model.columns=='request_attend_per_day']].copy()
X=datos_to_model[datos_to_model.columns[datos_to_model.columns!='request_attend_per_day']].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
#   ### 3.2 Normalizando y transformando las variables
#
# Normalizaremos salario y años de experiencia y todas las variables de edad mediante una estandarización

# %%
scaler = StandardScaler()

stand_xtrain=scaler.fit_transform(X_train[['wage_deflacted','years_exp_current_role','age','age2','age3','age4','age5']])
X_train[['wage_deflacted','years_exp_current_role','age','age2','age3','age4','age5']]=pd.DataFrame(stand_xtrain,columns=['wage_imputed','years_exp_current_role','age','age2','age3','age4','age5'],
                                                                                                 index=X_train.index)

stand_xtest=scaler.fit_transform(X_test[['wage_deflacted','years_exp_current_role','age','age2','age3','age4','age5']])
X_test[['wage_deflacted','years_exp_current_role','age','age2','age3','age4','age5']]=pd.DataFrame(stand_xtest,columns=['wage_imputed','years_exp_current_role','age','age2','age3','age4','age5'],
                                                                                                index=X_test.index)
# Out:
# c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %% [markdown]
# ### 3.3 Aplicando un box cox
#
# Se aplica la transformación Box-Cox sobre la variable `request_attend_per_day` una vez ya se crea el train set y el test set

# %%
from scipy import stats
ytrain_transformed, box_cox_lambda_ytrain = stats.boxcox(y_train.request_attend_per_day)
ytest_transformed, box_cox_lambda_ytest = stats.boxcox(y_test.request_attend_per_day)

# %%
sns.set_theme()
sns.set_style('white')
plt.figure(figsize=(10,15))

plt.subplot(2,2,1)
sns.histplot(ytrain_transformed)
plt.title('Response variable train Box-cox transformed ')

plt.subplot(2,2,2)
sns.histplot(y_train.request_attend_per_day)
plt.title('Response variable train Original')

plt.subplot(2,2,3)
sns.histplot(ytest_transformed)
plt.title('Response variable test Box-cox transformed')

plt.subplot(2,2,4)
sns.histplot(y_test.request_attend_per_day)
plt.title('Response variable test Original')
# Out:
# Text(0.5, 1.0, 'Response variable test Original')

# %% [markdown]
# La gráfica anterior muestra que sí es útil hacer la transformacion de **Box-Cox**, ya que le disminuye el sesgo y mejorar la distribución de lso datos. por lo cual, deberíamos aplicarla.

# %%
#X_train_extended = sm.add_constant(X_train)
X_train_extended = X_train.copy()
X_train_extended['month']=X_train_extended.month.astype('category')
X_train_extended['gender']=X_train_extended.gender.astype('category')
X_train_extended['is_special_population']=X_train_extended.is_special_population.astype('category')
X_train_extended['any_disability']=X_train_extended.any_disability.astype('category')
X_train_extended['MUNICIPIO_DE_RESIDENCIA']=X_train_extended.MUNICIPIO_DE_RESIDENCIA.astype('category')
X_train_extended['home_type']=X_train_extended.home_type.astype('category')
X_train_extended['PROFESION']=X_train_extended.PROFESION.astype('category')
X_train_extended['marital_status']=X_train_extended.marital_status.astype('category')
X_train_extended['total_depedants']=X_train_extended.total_depedants.astype('category')
X_train_extended['ESTRATO_SOCIAL']=X_train_extended.ESTRATO_SOCIAL.astype('category')
X_train_extended['education_level']=X_train_extended.education_level.astype('category')

# %%
X_train_extended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1178 entries, 98 to 1061
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   month                    1178 non-null   category
#  1   gender                   1178 non-null   category
#  2   is_special_population    1178 non-null   category
#  3   any_disability           1178 non-null   category
#  4   MUNICIPIO_DE_RESIDENCIA  1178 non-null   category
#  5   home_type                1178 non-null   category
#  6   education_level          1178 non-null   category
#  7   PROFESION                1178 non-null   category
#  8   marital_status           1178 non-null   category
#  9   total_depedants          1178 non-null   category
#  10  ESTRATO_SOCIAL           1178 non-null   category
#  11  wage_deflacted           1178 non-null   float64
#  12  age                      1176 non-null   float64
#  13  years_exp_current_role   1176 non-null   float64
#  14  age2                     1176 non-null   float64
#  15  age3                     1176 non-null   float64
#  16  age4                     1176 non-null   float64
#  17  age5                     1176 non-null   float64
# dtypes: category(11), float64(7)
# memory usage: 89.0 KB

# %%
data_train=X_train_extended.copy()
data_train['request_per_day']=ytrain_transformed

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1178 entries, 98 to 1061
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   month                    1178 non-null   category
#  1   gender                   1178 non-null   category
#  2   is_special_population    1178 non-null   category
#  3   any_disability           1178 non-null   category
#  4   MUNICIPIO_DE_RESIDENCIA  1178 non-null   category
#  5   home_type                1178 non-null   category
#  6   education_level          1178 non-null   category
#  7   PROFESION                1178 non-null   category
#  8   marital_status           1178 non-null   category
#  9   total_depedants          1178 non-null   category
#  10  ESTRATO_SOCIAL           1178 non-null   category
#  11  wage_deflacted           1178 non-null   float64
#  12  age                      1176 non-null   float64
#  13  years_exp_current_role   1176 non-null   float64
#  14  age2                     1176 non-null   float64
#  15  age3                     1176 non-null   float64
#  16  age4                     1176 non-null   float64
#  17  age5                     1176 non-null   float64
#  18  request_per_day          1178 non-null   float64
# dtypes: category(11), float64(8)
# memory usage: 98.2 KB

# %%
## usar esto para crear la fórmula dentro del modelo
formula='request_per_day~'
for i in range(len(data_train.columns)):
    if i ==0 and data_train.columns[i]!='request_per_day':
        formula= formula + data_train.columns[i]
    elif data_train.columns[i]!='request_per_day' and i !=0:
        formula= formula+'+'+ data_train.columns[i]
    else:
        continue

# %%
linear_model_baseline=smf.ols(formula=formula,data=data_train).fit()

# %%
linear_model_baseline.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        request_per_day   R-squared:                       0.589
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     30.28
# Date:                Thu, 07 Jul 2022   Prob (F-statistic):          1.68e-178
# Time:                        20:07:06   Log-Likelihood:                -2565.6
# No. Observations:                1176   AIC:                             5239.
# Df Residuals:                    1122   BIC:                             5513.
# Df Model:                          53
# Covariance Type:            nonrobust
# ========================================================================================================================================================================
#                                                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                              -12.6834      1.220    -10.394      0.000     -15.078     -10.289
# month[T.2]                                                                                               0.7102      0.310      2.291      0.022       0.102       1.319
# month[T.3]                                                                                               0.2803      0.302      0.927      0.354      -0.313       0.874
# month[T.4]                                                                                              -0.2472      0.300     -0.825      0.409      -0.835       0.341
# month[T.5]                                                                                              -0.3098      0.333     -0.931      0.352      -0.962       0.343
# month[T.6]                                                                                              -0.2586      0.324     -0.799      0.424      -0.893       0.376
# month[T.7]                                                                                               0.1365      0.332      0.411      0.681      -0.514       0.787
# month[T.8]                                                                                               0.2582      0.325      0.795      0.427      -0.379       0.895
# month[T.9]                                                                                               0.2217      0.323      0.687      0.492      -0.411       0.855
# month[T.10]                                                                                              0.5071      0.322      1.577      0.115      -0.124       1.138
# month[T.11]                                                                                              0.3292      0.327      1.008      0.314      -0.312       0.970
# month[T.12]                                                                                             -0.6246      0.313     -1.994      0.046      -1.239      -0.010
# gender[T.MALE]                                                                                           1.2026      0.650      1.851      0.064      -0.072       2.478
# gender[T.OTHER]                                                                                       1.904e-11   4.59e-12      4.146      0.000       1e-11    2.81e-11
# is_special_population[T.MADRE CABEZA DE FAMILIA]                                                        10.2007      2.161      4.720      0.000       5.960      14.441
# is_special_population[T.MUJER GESTANTE]                                                                 17.8445      4.207      4.241      0.000       9.589      26.100
# is_special_population[T.NO APLICA]                                                                      16.1349      1.775      9.088      0.000      12.651      19.618
# is_special_population[T.VICTIVA CONFLICTO ARMADO]                                                       27.7283      2.299     12.061      0.000      23.217      32.239
# total_depedants[T.1.0]                                                                                   3.6916      0.666      5.540      0.000       2.384       4.999
# total_depedants[T.2.0]                                                                                  -0.4661      0.584     -0.798      0.425      -1.613       0.680
# total_depedants[T.3.0]                                                                                  11.7272      1.250      9.384      0.000       9.275      14.179
# total_depedants[T.4.0]                                                                                   5.8332      0.795      7.340      0.000       4.274       7.392
# total_depedants[T.7.0]                                                                                   6.7809      1.036      6.545      0.000       4.748       8.814
# total_depedants[T.8.0]                                                                                  17.5400      2.481      7.069      0.000      12.672      22.408
# total_depedants[T.nan]                                                                                   1.5559      0.986      1.578      0.115      -0.379       3.490
# ESTRATO_SOCIAL[T.2.0]                                                                                   -0.7592      0.616     -1.232      0.218      -1.968       0.449
# ESTRATO_SOCIAL[T.3.0]                                                                                    0.8947      0.535      1.671      0.095      -0.156       1.945
# ESTRATO_SOCIAL[T.nan]                                                                                   -9.8063      1.601     -6.126      0.000     -12.947      -6.666
# wage_deflacted                                                                                          -0.2929      0.091     -3.235      0.001      -0.471      -0.115
# age                                                                                                    180.2225     50.302      3.583      0.000      81.526     278.919
# years_exp_current_role                                                                                   2.5089      0.390      6.436      0.000       1.744       3.274
# age2                                                                                                  -823.5412    208.179     -3.956      0.000   -1232.005    -415.078
# age3                                                                                                  1443.8717    349.342      4.133      0.000     758.434    2129.309
# age4                                                                                                 -1175.0654    279.040     -4.211      0.000   -1722.565    -627.566
# age5                                                                                                   368.0364     87.816      4.191      0.000     195.734     540.339
# ==============================================================================
# Omnibus:                       64.084   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.680
# Skew:                          -0.464   Prob(JB):                     4.55e-21
# Kurtosis:                       4.026   Cond. No.                     2.26e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.16e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
linear_model_baseline.pvalues.index[np.where(linear_model_baseline.pvalues<0.05/len(linear_model_baseline.pvalues))].to_frame().reset_index(drop=True)
# Out:
#                                                     0
# 0                                           Intercept
# 1                                     gender[T.OTHER]
# 2    is_special_population[T.MADRE CABEZA DE FAMILIA]
# 3             is_special_population[T.MUJER GESTANTE]
# 4                  is_special_population[T.NO APLICA]
# 5   is_special_population[T.VICTIVA CONFLICTO ARMADO]
# 6                       any_disability[T.no_reported]
# 7                   MUNICIPIO_DE_RESIDENCIA[T.cerete]
# 8           MUNICIPIO_DE_RESIDENCIA[T.cienaga_de_oro]
# 9              MUNICIPIO_DE_RESIDENCIA[T.montelibano]
# 10                MUNICIPIO_DE_RESIDENCIA[T.monteria]
# 11            MUNICIPIO_DE_RESIDENCIA[T.planeta_rica]
# 12                 MUNICIPIO_DE_RESIDENCIA[T.sahagun]
# 13                              home_type[T.FAMILIAR]
# 14                                 home_type[T.OTHER]
# 15                                home_type[T.PROPIA]
# 16                     education_level[T.PROFESIONAL]
# 17                         education_level[T.TECNICO]
# 18                       education_level[T.TECNOLOGO]
# 19                        PROFESION[T.admin_empresas]
# 20                 PROFESION[T.admin_servicios_salud]
# 21                    PROFESION[T.agente_call_center]
# 22              PROFESION[T.asistente_administrativo]
# 23               PROFESION[T.auxiliar administrativa]
# 24                   PROFESION[T.auxiliar_enfermeria]
# 25                          PROFESION[T.secretariado]
# 26  PROFESION[T.secretariado y asisten administrat...
# 27  PROFESION[T.tecnico auxiliar en auxiliar conta...
# 28                         marital_status[T.DIVORCED]
# 29                          marital_status[T.MARRIED]
# 30                            marital_status[T.OTHER]
# 31                           marital_status[T.SINGLE]
# 32                             total_depedants[T.1.0]
# 33                             total_depedants[T.3.0]
# 34                             total_depedants[T.4.0]
# 35                             total_depedants[T.7.0]
# 36                             total_depedants[T.8.0]
# 37                              ESTRATO_SOCIAL[T.nan]
# 38                                                age
# 39                             years_exp_current_role
# 40                                               age2
# 41                                               age3
# 42                                               age4
# 43                                               age5

# %%
linear_model_baseline.fvalue ### valor del ANOVA agregado del modelo.
# Out:
# 30.284164250120487

# %%
anova_test=sm.stats.anova_lm(linear_model_baseline,typ=1)

# %%
print(anova_test)
# Out:
#                              df       sum_sq     mean_sq          F  \
# month                      11.0   109.912503    9.992046   2.073973
# gender                      2.0    80.933915   40.466957   8.399420
# is_special_population       4.0   298.118199   74.529550  15.469534
# any_disability              1.0     7.951165    7.951165   1.650363
# MUNICIPIO_DE_RESIDENCIA     8.0  1251.293454  156.411682  32.465188
# home_type                   3.0   107.298132   35.766044   7.423687
# education_level             3.0   251.487231   83.829077  17.399767
# PROFESION                  10.0  3104.604514  310.460451  64.439924
# marital_status              4.0   430.256908  107.564227  22.326292
# total_depedants             7.0  1104.495755  157.785108  32.750260
# ESTRATO_SOCIAL              3.0   356.987046  118.995682  24.699032
# wage_deflacted              1.0    15.945694   15.945694   3.309727
# age                         1.0     8.515106    8.515106   1.767416
# years_exp_current_role      1.0   360.974688  360.974688  74.924782
# age2                        1.0   103.490840  103.490840  21.480810
# age3                        1.0    75.552938   75.552938  15.681951
# age4                        1.0     0.661119    0.661119   0.137223
# age5                        1.0    84.777305   84.777305  17.596583
# Residual                 1122.0  5405.602650    4.817828        NaN
#
#                                 PR(>F)
# month                     1.963419e-02
# gender                    2.394511e-04
# is_special_population     2.526521e-12
# any_disability            1.991747e-01
# MUNICIPIO_DE_RESIDENCIA   3.765045e-46
# home_type                 6.330014e-05
# education_level           4.787411e-11
# PROFESION                2.023768e-103
# marital_status            9.283274e-18
# total_depedants           1.382169e-41
# ESTRATO_SOCIAL            1.770121e-15
# wage_deflacted            6.913736e-02
# age                       1.839724e-01
# years_exp_current_role    1.672812e-17
# age2                      3.992789e-06
# age3                      7.965598e-05
# age4                      7.111270e-01
# age5                      2.946147e-05
# Residual                           NaN

# %%
#model_region_no_oldest_box_cox=smf.ols(
 #   formula='Cost_BC_transformed~Region+group_size+homeowner+car_age+car_value+age_youngest+married_couple+C_previous+duration_previous+A+E+F+G',
  #  data=train_expanded).fit()

# %% [markdown]
# En la regresión ejecutada arriba, se puede observar que el R squared se acerca al 58% de explicación, el cual no  no es malo, pero definitivamente no es el mejor; del mismo modo, haciendo pruebas de hipotesis individuales aplicando la corección de **Bonferroni**, se observa que las únicas variables que individualmente se eliminan por baja significancia estadística es la variable categoria `Months` y el `wage_deflacted`. Este último puede estar atado al hecho de que el cargo es estandar y de baja cualificación profesional, haciendo que que la diferencia de salarios a lo largo de los cargos no sea significativa. De igual manera, note que al tener una variable dependiente continua y casi normal (es distribución), es posible ver el análsis ANOVA, la cual muestra que en general, alguna o varias de los betas son diferentes de cero.

# %% [markdown]
# Dado lo anterior, se puede observar que con las variables significativas se puede volver a correr un modelo de la siguiente forma:

# %%
formula2='request_per_day~gender+is_special_population+any_disability+MUNICIPIO_DE_RESIDENCIA+home_type+education_level+PROFESION+marital_status+total_depedants+ESTRATO_SOCIAL+age+years_exp_current_role+age2+age3+age4+age5'

# %%
data_train.education_level.unique()
# Out:
# ['PROFESIONAL', 'TECNICO', 'TECNOLOGO', 'OTHER']
# Categories (4, object): ['OTHER', 'PROFESIONAL', 'TECNICO', 'TECNOLOGO']

# %%
linear_model_baseline_mod=smf.ols(formula=formula2,data=data_train).fit() 
linear_model_baseline_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        request_per_day   R-squared:                       0.573
# Model:                            OLS   Adj. R-squared:                  0.557
# Method:                 Least Squares   F-statistic:                     37.06
# Date:                Thu, 07 Jul 2022   Prob (F-statistic):          1.19e-178
# Time:                        20:07:24   Log-Likelihood:                -2587.9
# No. Observations:                1176   AIC:                             5260.
# Df Residuals:                    1134   BIC:                             5473.
# Df Model:                          41
# Covariance Type:            nonrobust
# ========================================================================================================================================================================
#                                                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                              -12.0141      1.210     -9.931      0.000     -14.388      -9.640
# gender[T.MALE]                                                                                           1.1100      0.658      1.687      0.092      -0.181       2.401
# gender[T.OTHER]                                                                                       9.989e-12   2.23e-12      4.485      0.000    5.62e-12    1.44e-11
# is_special_population[T.MADRE CABEZA DE FAMILIA]                                                        10.1129      2.185      4.627      0.000       5.825      14.401
# is_special_population[T.MUJER GESTANTE]                                                                 17.7599      4.258      4.171      0.000       9.406      26.114
# is_special_population[T.NO APLICA]                                                                      15.5141      1.787      8.684      0.000      12.009      19.020
# is_special_population[T.VICTIVA CONFLICTO ARMADO]                                                       26.0912      2.262     11.536      0.000      21.654      30.529
# any_disability[T.no_reported]                                                                        -1.233e-11   2.84e-12     -4.341      0.000   -1.79e-11   -6.76e-12
# MUNICIPIO_DE_RESIDENCIA[T.cerete]                                                                       17.7599      4.258      4.171      0.000       9.406      26.114
# MUNICIPIO_DE_RESIDENCIA[T.cienaga_de_oro]                                                               -8.3003      1.097     -7.568      0.000     -10.452      -6.148
# MUNICIPIO_DE_RESIDENCIA[T.montelibano]                                                                  10.0164      1.683      5.950      0.000       6.713      13.319
# MUNICIPIO_DE_RESIDENCIA[T.monteria]                                                                     -9.5507      1.080     -8.842      0.000     -11.670      -7.431
# MUNICIPIO_DE_RESIDENCIA[T.murindo]                                                                       0.5237      1.168      0.448      0.654      -1.769       2.816
# MUNICIPIO_DE_RESIDENCIA[T.planeta_rica]                                                                 -9.7998      1.167     -8.401      0.000     -12.089      -7.511
# MUNICIPIO_DE_RESIDENCIA[T.sahagun]                                                                     -14.8692      1.217    -12.219      0.000     -17.257     -12.482
# MUNICIPIO_DE_RESIDENCIA[T.san_pelayo]                                                                    2.2059      1.530      1.442      0.150      -0.796       5.208
# home_type[T.FAMILIAR]                                                                                    3.3266      0.475      7.000      0.000       2.394       4.259
Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.773
# Skew:                          -0.445   Prob(JB):                     8.72e-20
# Kurtosis:                       3.999   Cond. No.                     1.41e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.94e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# Con base en el modelo base, podemos encontrar un perfil potencial base que nos dice que: la mayor productividad puede ser de un perfil que sea hombre, que no tenga ninguna condición especial (o provenga del conflicto armado) que provenga de Cereté (Cordoba), que viva en casa familiar, con un nivel profesional por fuera de los tradicionales y que tenga profesiones relacionadas a secretariado y/o asistete administrativo, donde como maximo tenga 3 dependientes (probablemente 8 dependientes observados en el model muestra una significacia grande por temas a pocos datos), con estrato social 3 y con mayor años de experiencia. La edad es un factor positivamente fundamental para la productividad, pero va disminuyendo marginalmente a medida que aumenta.

# %% [markdown]
# Debido a que este modelo es de referencia, decidimos no hacer ninguna prueba de supuestos por el momento y ver primero si logra desempeñarse bien frente a otros modelos de ML, más flexible en sus supuestos

# %% [markdown]
# ## 4.0 Encontrando el modelo adecuado
#
# Se empiza a hacer las investigaciones avanzadas para determinar cual es el mejor modelo

# %% [markdown]
# ### 4.1 Modelo de regresión
#
# Iniciamos con modelos de regresión utilizando la herramienta built-in en python llamada de pycaret

# %%
datos_to_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1683 entries, 0 to 1682
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   month                    1683 non-null   int64
#  1   gender                   1683 non-null   object
#  2   is_special_population    1683 non-null   object
#  3   any_disability           1683 non-null   object
#  4   MUNICIPIO_DE_RESIDENCIA  1683 non-null   object
#  5   home_type                1683 non-null   object
#  6   education_level          1683 non-null   object
#  7   PROFESION                1683 non-null   object
#  8   marital_status           1683 non-null   object
#  9   total_depedants          1683 non-null   object
#  10  ESTRATO_SOCIAL           1683 non-null   object
#  11  wage_deflacted           1683 non-null   float64
#  12  age                      1680 non-null   float64
#  13  years_exp_current_role   1680 non-null   float64
#  14  request_attend_per_day   1683 non-null   float64
#  15  age2                     1680 non-null   float64
#  16  age3                     1680 non-null   float64
#  17  age4                     1680 non-null   float64
#  18  age5                     1680 non-null   float64
# dtypes: float64(8), int64(1), object(10)
# memory usage: 263.0+ KB

# %% [markdown]
# ### 4.1.1 Setting up the parameters
#
# Notará que la siguiente linea permite que pycaret haga gran parte pornosotros, primero le relacionamos las variables que serán categóricas y permitimos que:
# 1) se estandarice (mediante z score) las variables numéricas
# 2) ignorará las variables que posean 0 varianza aproximadamente
# 3) permitirá crear una gama e variables más grande, a través de combinaciones de todas las variables.
# 4) elimina una de las variables, de aquel par que poseauna correlación de 85% o más
# 5) como se vio anteriormente, la transformación de la variable respuesta puede ser útil, por lo que permitimos hacer la transformación de Box-cox
# 6) Se implementa una combinación de Random_forest y regresiones lineales para escoger solo las variables más representativas.

# %%
datos_to_model=datos_to_model.drop(columns='month')

# %%
datos_to_model.to_excel(os.path.join(ruta_insumos,'master_data','data_master_ready_to_model.xlsx'))

# %%
from pycaret.regression import *
set_model = setup(datos_to_model, target = 'request_attend_per_day',categorical_features=['gender','is_special_population','any_disability','MUNICIPIO_DE_RESIDENCIA','home_type','education_level',
                                                                                  'marital_status','PROFESION','total_depedants','ESTRATO_SOCIAL'],
          normalize=True,normalize_method='zscore',feature_interaction=True,ignore_low_variance=True,transform_target=True,transform_target_method='box-cox',
          feature_selection=True,feature_selection_threshold=0.85,remove_multicollinearity=True,multicollinearity_threshold=0.85,session_id=1229,train_size=0.70,fold_strategy='kfold',
                 fold=10)
# Out:
# <style type="text/css">
# #T_4bc34_row3_col1, #T_4bc34_row27_col1, #T_4bc34_row34_col1, #T_4bc34_row40_col1, #T_4bc34_row42_col1, #T_4bc34_row50_col1, #T_4bc34_row53_col1, #T_4bc34_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4bc34_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bc34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bc34_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_4bc34_row0_col1" class="data row0 col1" >1229</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4bc34_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4bc34_row1_col1" class="data row1 col1" >request_attend_per_day</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4bc34_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_4bc34_row2_col1" class="data row2 col1" >(1683, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4bc34_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_4bc34_row3_col1" class="data row3 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4bc34_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_4bc34_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4bc34_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_4bc34_row5_col1" class="data row5 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4bc34_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_4bc34_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4bc34_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_4bc34_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4bc34_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_4bc34_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4bc34_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_4bc34_row9_col1" class="data row9 col1" >(1178, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4bc34_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_4bc34_row10_col1" class="data row10 col1" >(505, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4bc34_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_4bc34_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4bc34_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_4bc34_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4bc34_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_4bc34_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4bc34_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_4bc34_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4bc34_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_4bc34_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4bc34_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_4bc34_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4bc34_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_4bc34_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4bc34_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_4bc34_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4bc34_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_4bc34_row19_col1" class="data row19 col1" >6f6f</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4bc34_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_4bc34_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4bc34_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_4bc34_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4bc34_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_4bc34_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_4bc34_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_4bc34_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_4bc34_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_4bc34_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_4bc34_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_4bc34_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_4bc34_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_4bc34_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_4bc34_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_4bc34_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_4bc34_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_4bc34_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_4bc34_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_4bc34_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4bc34_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id=

# %% [markdown]
# Para este caso, corremos el modelo y seleccionamos el mejor de acuerdo al que tenga el mínimo RMSE. Para ello, se observa que el Extra Tree para regresión es el menor, mejorando en promedio en casi 4 unidades el modelo de regresión lineal y casi aumentando en 20 puntos porcnentales su R2.

# %%
best=compare_models(sort='RMSE')
# Out:
# <style type="text/css">
# #T_0740c_ th {
#   text-align: left;
# }
# #T_0740c_row0_col0, #T_0740c_row0_col5, #T_0740c_row0_col6, #T_0740c_row1_col0, #T_0740c_row1_col1, #T_0740c_row1_col2, #T_0740c_row1_col3, #T_0740c_row1_col4, #T_0740c_row1_col5, #T_0740c_row1_col6, #T_0740c_row2_col0, #T_0740c_row2_col1, #T_0740c_row2_col2, #T_0740c_row2_col3, #T_0740c_row2_col4, #T_0740c_row3_col0, #T_0740c_row3_col1, #T_0740c_row3_col2, #T_0740c_row3_col3, #T_0740c_row3_col4, #T_0740c_row3_col5, #T_0740c_row3_col6, #T_0740c_row4_col0, #T_0740c_row4_col1, #T_0740c_row4_col2, #T_0740c_row4_col3, #T_0740c_row4_col4, #T_0740c_row4_col5, #T_0740c_row4_col6, #T_0740c_row5_col0, #T_0740c_row5_col1, #T_0740c_row5_col2, #T_0740c_row5_col3, #T_0740c_row5_col4, #T_0740c_row5_col5, #T_0740c_row5_col6, #T_0740c_row6_col0, #T_0740c_row6_col1, #T_0740c_row6_col2, #T_0740c_row6_col3, #T_0740c_row
None,
#                                                               min_impurity_decrease=0.0,
#                                                               min_impurity_split=None,
#                                                               min_samples_leaf=1,
#                                                               min_samples_split=2,
#                                                               min_weight_fraction_leaf=0.0,
#                                                               n_estimators=100,
#                                                               n_jobs=-1,
#                                                               oob_score=False,
#                                                               random_state=1229,
#                                                               verbose=0,
#                                                               warm_start=False),
#                                 verbose=0, warm_start=False)

# %%
modelo_seleccionado=create_model(best,criterion='mse') ## se crea el modelo minimizando el MSE sobre el modelo con menor RMSE
# Out:
# <style type="text/css">
# #T_76c8a_row10_col0, #T_76c8a_row10_col1, #T_76c8a_row10_col2, #T_76c8a_row10_col3, #T_76c8a_row10_col4, #T_76c8a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_76c8a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76c8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76c8a_row0_col0" class="data row0 col0" >8.5149</td>
#       <td id="T_76c8a_row0_col1" class="data row0 col1" >205.3878</td>
#       <td id="T_76c8a_row0_col2" class="data row0 col2" >14.3314</td>
#       <td id="T_76c8a_row0_col3" class="data row0 col3" >0.8036</td>
#       <td id="T_76c8a_row0_col4" class="data row0 col4" >0.5914</td>
#       <td id="T_76c8a_row0_col5" class="data row0 col5" >0.9024</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76c8a_row1_col0" class="data row1 col0" >11.8426</td>
#       <td id="T_76c8a_row1_col1" class="data row1 col1" >475.3477</td>
#       <td id="T_76c8a_row1_col2" class="data row1 col2" >21.8025</td>
#       <td id="T_76c8a_row1_col3" class="data row1 col3" >0.6229</td>
#       <td id="T_76c8a_row1_col4" class="data row1 col4" >0.6585</td>
#       <td id="T_76c8a_row1_col5" class="data row1 col5" >1.2094</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76c8a_row2_col0" class="data row2 col0" >8.5246</td>
#       <td id="T_76c8a_row2_col1" class="data row2 col1" >183.1296</td>
#       <td id="T_76c8a_row2_col2" class="data row2 col2" >13.5325</td>
#       <td id="T_76c8a_row2_col3" class="data row2 col3" >0.8612</td>
#       <td id="T_76c8a_row2_col4" class="data row2 col4" >0.4850</td>
#       <td id="T_76c8a_row2_col5" class="data row2 col5" >1.0470</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76c8a_row3_col0" class="data row3 col0" >11.3570</td>
#       <td id="T_76c8a_row3_col1" class="data row3 col1" >325.9814</td>
#       <td id="T_76c8a_row3_col2" class="data row3 col2" >18.0550</td>
#       <td id="T_76c8a_row3_col3" class="data row3 col3" >0.6517</td>
#       <td id="T_76c8a_row3_col4" class="data row3 col4" >0.6671</td>
#       <td id="T_76c8a_row3_col5" class="data row3 col5" >2.0376</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76c8a_row4_col0" class="data row4 col0" >9.3941</td>
#       <td id="T_76c8a_row4_col1" class="data row4 col1" >223.9811</td>
#       <td id="T_76c8a_row4_col2" class="data row4 col2" >14.9660</td>
#       <td id="T_76c8a_row4_col3" class="data row4 col3" >0.8295</td>
#       <td id="T_76c8a_row4_col4" class="data row4 col4" >0.4120</td>
#       <td id="T_76c8a_row4_col5" class="data row4 col5" >0.6091</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76c8a_row5_col0" class="data row5 col0" >10.1870</td>
#       <td id="T_76c8a_row5_col1" class="data row5 col1" >272.7536</td>
#       <td id="T_76c8a_row5_col2" class="data row5 col2" >16.5153</td>
#       <td id="T_76c8a_row5_col3" class="data row5 col3" >0.7402</td>
#       <td id="T_76c8a_row5_col4" class="data row5 col4" >0.6318</td>
#       <td id="T_76c8a_row5_col5" class="data row5 col5" >1.6644</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76c8a_row6_col0" class="data row6 col0" >9.6995</td>
#       <td id="T_76c8a_row6_col1" class="data row6 col1" >270.5769</td>
#       <td id="T_76c8a_row6_col2" class="data row6 col2" >16.4492</td>
#       <td id="T_76c8a_row6_col3" class="data row6 col3" >0.7996</td>
#       <td id="T_76c8a_row6_col4" class="data row6 col4" >0.5057</td>
#       <td id="T_76c8a_row6_col5" class="data row6 col5" >2.5458</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76c8a_row7_col0" class="data row7 col0" >7.0065</td>
#       <td id="T_76c8a_row7_col1" class="data row7 col1" >114.1850</td>
#       <td id="T_76c8a_row7_col2" class="data row7 col2" >10.6857</td>
#       <td id="T_76c8a_row7_col3" class="data row7 col3" >0.8754</td>
#       <td id="T_76c8a_row7_col4" class="data row7 col4" >0.5536</td>
#       <td id="T_76c8a_row7_col5" class="data row7 col5" >8.2162</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76c8a_row8_col0" class="data row8 col0" >10.6807</td>
#       <td id="T_76c8a_row8_col1" class="data row8 col1" >290.3891</td>
#       <td id="T_76c8a_row8_col2" class="data row8 col2" >17.0408</td>
#       <td id="T_76c8a_row8_col3" class="data row8 col3" >0.7979</td>
#       <td id="T_76c8a_row8_col4" class="data row8 col4" >0.5401</td>
#       <td id="T_76c8a_row8_col5" class="data row8 col5" >0.5085</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76c8a_row9_col0" class="data row9 col0" >8.9366</td>
#       <td id="T_76c8a_row9_col1" class="data row9 col1" >235.9325</td>
#       <td id="T_76c8a_row9_col2" class="data row9 col2" >15.3601</td>
#       <td id="T_76c8a_row9_col3" class="data row9 col3" >0.7442</td>
#       <td id="T_76c8a_row9_col4" class="data row9 col4" >0.5988</td>
#       <td id="T_76c8a_row9_col5" class="data row9 col5" >1.4003</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_76c8a_row10_col0" class="data row10 col0" >9.6144</td>
#       <td id="T_76c8a_row10_col1" class="data row10 col1" >259.7665</td>
#       <td id="T_76c8a_row10_col2" class="data row10 col2" >15.8738</td>
#       <td id="T_76c8a_row10_col3" class="data row10 col3" >0.7726</td>
#       <td id="T_76c8a_row10_col4" class="data row10 col4" >0.5644</td>
#       <td id="T_76c8a_row10_col5" class="data row10 col5" >2.0141</td>
#     </tr>
#     <tr>
#       <th id="T_76c8a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_76c8a_row11_col0" class="data row11 col0" >1.3849</td>
#       <td id="T_76c8a_row11_col1" class="data row11 col1" >91.6274</td>
#       <td id="T_76c8a_row11_col2" class="data row11 col2" >2.7906</td>
#       <td id="T_76c8a_row11_col3" class="data row11 col3" >0.0793</td>
#       <td id="T_76c8a_row11_col4" class="data row11 col4" >0.0772</td>
#       <td id="T_76c8a_row11_col5" class="data row11 col5" >2.1519</td>
#     </tr>
#   </tbody>
# </table>

# %%
RMSE_best_model_notuned=pull()

# %%
RMSE_notuned=RMSE_best_model_notuned.loc['Mean'].RMSE

# %% [markdown]
# A pesar que Extra Tree parece ser el más útil para este caso, tendríamos un problema y sería al establecer todos los hiperparámetros que requiere este método. Para este caso, se utiliza el proceso de 'tuning' que trata de optimizar el RMSE (minimizarlo) de acuerdo al conjunto de hiperparámetros que serán escogidos a través de optimización bayesiana.

# %% [markdown]
# ### 4.1.2 Tuneando el modelo
#
#
# Acá se planea optimizar los hiperparámetros del modelo elegido para ver si es posible mejorar su rendimiento

# %%
#pip install tune-sklearn ray[tune]* 
#modelo_tuneado=tune_model(modelo_seleccionado, search_library = 'tune-sklearn', search_algorithm = 'hyperopt',choose_better=True,optimize='RMSE',n_iter=30)

modelo_tuneado=tune_model(modelo_seleccionado, search_library = 'optuna',choose_better=True,optimize='RMSE',n_iter=30)
# Out:
# <style type="text/css">
# #T_4085c_row10_col0, #T_4085c_row10_col1, #T_4085c_row10_col2, #T_4085c_row10_col3, #T_4085c_row10_col4, #T_4085c_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4085c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4085c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4085c_row0_col0" class="data row0 col0" >9.9355</td>
#       <td id="T_4085c_row0_col1" class="data row0 col1" >306.9269</td>
#       <td id="T_4085c_row0_col2" class="data row0 col2" >17.5193</td>
#       <td id="T_4085c_row0_col3" class="data row0 col3" >0.7066</td>
#       <td id="T_4085c_row0_col4" class="data row0 col4" >0.6065</td>
#       <td id="T_4085c_row0_col5" class="data row0 col5" >1.0823</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4085c_row1_col0" class="data row1 col0" >12.3782</td>
#       <td id="T_4085c_row1_col1" class="data row1 col1" >473.4006</td>
#       <td id="T_4085c_row1_col2" class="data row1 col2" >21.7578</td>
#       <td id="T_4085c_row1_col3" class="data row1 col3" >0.6244</td>
#       <td id="T_4085c_row1_col4" class="data row1 col4" >0.6778</td>
#       <td id="T_4085c_row1_col5" class="data row1 col5" >1.5012</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4085c_row2_col0" class="data row2 col0" >10.6775</td>
#       <td id="T_4085c_row2_col1" class="data row2 col1" >293.4117</td>
#       <td id="T_4085c_row2_col2" class="data row2 col2" >17.1293</td>
#       <td id="T_4085c_row2_col3" class="data row2 col3" >0.7776</td>
#       <td id="T_4085c_row2_col4" class="data row2 col4" >0.5608</td>
#       <td id="T_4085c_row2_col5" class="data row2 col5" >1.5020</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4085c_row3_col0" class="data row3 col0" >11.8467</td>
#       <td id="T_4085c_row3_col1" class="data row3 col1" >294.9402</td>
#       <td id="T_4085c_row3_col2" class="data row3 col2" >17.1738</td>
#       <td id="T_4085c_row3_col3" class="data row3 col3" >0.6849</td>
#       <td id="T_4085c_row3_col4" class="data row3 col4" >0.7309</td>
#       <td id="T_4085c_row3_col5" class="data row3 col5" >2.0194</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4085c_row4_col0" class="data row4 col0" >12.1319</td>
#       <td id="T_4085c_row4_col1" class="data row4 col1" >330.3620</td>
#       <td id="T_4085c_row4_col2" class="data row4 col2" >18.1759</td>
#       <td id="T_4085c_row4_col3" class="data row4 col3" >0.7486</td>
#       <td id="T_4085c_row4_col4" class="data row4 col4" >0.5166</td>
#       <td id="T_4085c_row4_col5" class="data row4 col5" >0.8822</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4085c_row5_col0" class="data row5 col0" >10.2597</td>
#       <td id="T_4085c_row5_col1" class="data row5 col1" >248.4867</td>
#       <td id="T_4085c_row5_col2" class="data row5 col2" >15.7635</td>
#       <td id="T_4085c_row5_col3" class="data row5 col3" >0.7633</td>
#       <td id="T_4085c_row5_col4" class="data row5 col4" >0.6087</td>
#       <td id="T_4085c_row5_col5" class="data row5 col5" >1.5939</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4085c_row6_col0" class="data row6 col0" >11.2484</td>
#       <td id="T_4085c_row6_col1" class="data row6 col1" >357.9215</td>
#       <td id="T_4085c_row6_col2" class="data row6 col2" >18.9188</td>
#       <td id="T_4085c_row6_col3" class="data row6 col3" >0.7349</td>
#       <td id="T_4085c_row6_col4" class="data row6 col4" >0.5669</td>
#       <td id="T_4085c_row6_col5" class="data row6 col5" >2.8177</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4085c_row7_col0" class="data row7 col0" >9.5301</td>
#       <td id="T_4085c_row7_col1" class="data row7 col1" >224.9105</td>
#       <td id="T_4085c_row7_col2" class="data row7 col2" >14.9970</td>
#       <td id="T_4085c_row7_col3" class="data row7 col3" >0.7545</td>
#       <td id="T_4085c_row7_col4" class="data row7 col4" >0.6229</td>
#       <td id="T_4085c_row7_col5" class="data row7 col5" >7.4157</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4085c_row8_col0" class="data row8 col0" >13.5588</td>
#       <td id="T_4085c_row8_col1" class="data row8 col1" >495.7666</td>
#       <td id="T_4085c_row8_col2" class="data row8 col2" >22.2658</td>
#       <td id="T_4085c_row8_col3" class="data row8 col3" >0.6549</td>
#       <td id="T_4085c_row8_col4" class="data row8 col4" >0.5908</td>
#       <td id="T_4085c_row8_col5" class="data row8 col5" >0.8375</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4085c_row9_col0" class="data row9 col0" >9.0695</td>
#       <td id="T_4085c_row9_col1" class="data row9 col1" >207.2628</td>
#       <td id="T_4085c_row9_col2" class="data row9 col2" >14.3966</td>
#       <td id="T_4085c_row9_col3" class="data row9 col3" >0.7752</td>
#       <td id="T_4085c_row9_col4" class="data row9 col4" >0.5529</td>
#       <td id="T_4085c_row9_col5" class="data row9 col5" >1.4313</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4085c_row10_col0" class="data row10 col0" >11.0636</td>
#       <td id="T_4085c_row10_col1" class="data row10 col1" >323.3390</td>
#       <td id="T_4085c_row10_col2" class="data row10 col2" >17.8098</td>
#       <td id="T_4085c_row10_col3" class="data row10 col3" >0.7225</td>
#       <td id="T_4085c_row10_col4" class="data row10 col4" >0.6035</td>
#       <td id="T_4085c_row10_col5" class="data row10 col5" >2.1083</td>
#     </tr>
#     <tr>
#       <th id="T_4085c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4085c_row11_col0" class="data row11 col0" >1.3468</td>
#       <td id="T_4085c_row11_col1" class="data row11 col1" >91.7776</td>
#       <td id="T_4085c_row11_col2" class="data row11 col2" >2.4801</td>
#       <td id="T_4085c_row11_col3" class="data row11 col3" >0.0502</td>
#       <td id="T_4085c_row11_col4" class="data row11 col4" >0.0597</td>
#       <td id="T_4085c_row11_col5" class="data row11 col5" >1.8523</td>
#     </tr>
#   </tbody>
# </table>

# %%
modelo_seleccionado_tuneado=create_model(modelo_tuneado,criterion='mse')
# Out:
# <style type="text/css">
# #T_439d6_row10_col0, #T_439d6_row10_col1, #T_439d6_row10_col2, #T_439d6_row10_col3, #T_439d6_row10_col4, #T_439d6_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_439d6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_439d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_439d6_row0_col0" class="data row0 col0" >8.5149</td>
#       <td id="T_439d6_row0_col1" class="data row0 col1" >205.3878</td>
#       <td id="T_439d6_row0_col2" class="data row0 col2" >14.3314</td>
#       <td id="T_439d6_row0_col3" class="data row0 col3" >0.8036</td>
#       <td id="T_439d6_row0_col4" class="data row0 col4" >0.5914</td>
#       <td id="T_439d6_row0_col5" class="data row0 col5" >0.9024</td>
#     </tr>
#     <tr>
#       <th id="T_439d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_439d6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_439d6_row9_col0" class="data row9 col0" >8.9366</td>
#       <td id="T_439d6_row9_col1" class="data row9 col1" >235.9325</td>
#       <td id="T_439d6_row9_col2" class="data row9 col2" >15.3601</td>
#       <td id="T_439d6_row9_col3" class="data row9 col3" >0.7442</td>
#       <td id="T_439d6_row9_col4" class="data row9 col4" >0.5988</td>
#       <td id="T_439d6_row9_col5" class="data row9 col5" >1.4003</td>
#     </tr>
#     <tr>
#       <th id="T_439d6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_439d6_row10_col0" class="data row10 col0" >9.6144</td>
#       <td id="T_439d6_row10_col1" class="data row10 col1" >259.7665</td>
#       <td id="T_439d6_row10_col2" class="data row10 col2" >15.8738</td>
#       <td id="T_439d6_row10_col3" class="data row10 col3" >0.7726</td>
#       <td id="T_439d6_row10_col4" class="data row10 col4" >0.5644</td>
#       <td id="T_439d6_row10_col5" class="data row10 col5" >2.0141</td>
#     </tr>
#     <tr>
#       <th id="T_439d6_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_439d6_row11_col0" class="data row11 col0" >1.3849</td>
#       <td id="T_439d6_row11_col1" class="data row11 col1" >91.6274</td>
#       <td id="T_439d6_row11_col2" class="data row11 col2" >2.7906</td>
#       <td id="T_439d6_row11_col3" class="data row11 col3" >0.0793</td>
#       <td id="T_439d6_row11_col4" class="data row11 col4" >0.0772</td>
#       <td id="T_439d6_row11_col5" class="data row11 col5" >2.1519</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_tuned_results = pull()

# %%
model_selected_tuned=model_tuned_results.loc['Mean'].RMSE

# %% [markdown]
# Se saca el modelo tuneado y se compara con el sin tunear, logrando así escoger el que más bajo RMSE tenga

# %%
if model_selected_tuned>RMSE_notuned:
    final_model=model_selected_tuned
else:
    final_model=modelo_seleccionado

# %% [markdown]
# La siguiente permite crear ficheros y configuraciones para crear las imágenes que se van a correr en el Front-End para evitar gastos innecesarios computacionalmente hablando

# %%
os.chdir('C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Codigo\\Modelling')
all_data_final_model=finalize_model(final_model)
save_model(all_data_final_model, 'C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Models\\model_selected_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['gender',
#                                                              'is_special_population',
#                                                              'any_disability',
#                                                              'MUNICIPIO_DE_RESIDENCIA',
#                                                              'home_type',
#                                                              'education_level',
#                                                              'marital_status',
#                                                              'PROFESION',
#                                                              'total_depedants',
#                                                              'ESTRATO_SOCIAL'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],...
#                                                                                 ccp_alpha=0.0,
#                                                                                 criterion='mse',
#                                                                                 max_depth=None,
#                                                                                 max_features='auto',
#                                                                                 max_leaf_nodes=None,
#                                                                                 max_samples=None,
#                                                                                 min_impurity_decrease=0.0,
#                                                                                 min_impurity_split=None,
#                                                                                 min_samples_leaf=1,
#                                                                                 min_samples_split=2,
#                                                                                 min_weight_fraction_leaf=0.0,
#                                                                                 n_estimators=100,
#                                                                                 n_jobs=-1,
#                                                                                 oob_score=False,
#                                                                                 random_state=1229,
#                                                                                 verbose=0,
#                                                                                 warm_start=False),
#                                                   verbose=0,
#                                                   warm_start=False)]],
#           verbose=False),
#  'C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Models\\model_selected_pipeline.pkl')

# %%
save_config('C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Models\\model_selected_config')

# %%
import joblib
joblib.dump(final_model,'C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Models\\final_model_visualization.data')
# Out:
# ['C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Models\\final_model_visualization.data']

# %% [markdown]
# ### 5 Predicción del modelo
#
# Una vez se escoge el modelo, lo que se sugiere hacer es utilizar el modelo ganador sobre toda la data, y en el Front-End, se relacione las variables `gender`,`is_special_population`,`any_disability`,`MUNICIPIO_DE_RESIDENCIA`,`home_type`, `education_level`,`PROFESION`,`marital_status`,`total_depedants`,`ESTRATO_SOCIAL`, `age`, `years_exp_current_role`. Donde el sueldo será puesto internamente por la entidad de salud y las varables polinómicas de la edad, serán calculadaas ua vez se relacione la edad del candidato potencial.	 Para las variables `age`, `years_exp_current_role` su tipo de dato son numéricas y `ESTRATO_SOCIAL`, `total_depedants` parecen numericas pero tambien son categoricas ordinales.

# %% [markdown]
# **Pronostico de prueba**
# Para este caso. se hará un pronóstico de prueba con el fin de probar el modelo escogido.

# %%
#os.chdir('C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Codigo\\Modelling')
all_data_final_model=load_model('C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Models\\model_selected_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
##load_model('model_selected_pipeline')## para cargar de vuelta el modelo
age=50
gender='FEMALE'
is_special_population='NO APLICA'
municipio_living='monteria'
home_type='ARRENDADA'
education_level='PROFESIONAL'
PROFESION='admin_empresas'
marital_status='SINGLE'
total_dependants='1.0'
ESTRATO_SOCIAL='1.0'
years_exp_current_role=10

# %%
new_data=datos_to_model.iloc[[0,]].copy()
new_data=new_data.drop(columns='request_attend_per_day')
new_data['age']=float(age)
new_data['age2']=float(age)**2
new_data['age3']=float(age)**3
new_data['age4']=float(age)**4
new_data['age5']=float(age)**5
new_data['is_special_population']=is_special_population
new_data['municipio_living']=municipio_living
new_data['home_type']=home_type
new_data['education_level']=education_level
new_data['marital_status']=marital_status
new_data['total_dependants']=str(total_dependants)
new_data['ESTRATO_SOCIAL']=str(ESTRATO_SOCIAL)
new_data['years_exp_current_role']=float(years_exp_current_role)
new_data['PROFESION']=PROFESION

# %%
predicted_value=predict_model(all_data_final_model, data = new_data)

# %%
print(float(predicted_value.Label)) ### este es los requerimientos atendidos por dia que tendrá esa persona
# Out:
# 17.603543824217304

# %%
unicos={}
for i in datos_to_model.select_dtypes('object' or 'category').columns.to_list():
    unicos[i]=datos_to_model[i].unique()

# %% [markdown]
# Se crea un fichero para guardar las categorias que se usarán en el Front-End

# %%
import joblib
joblib.dump(unicos,'unicos_categorias.data')
# Out:
# ['unicos_categorias.data']

# %% [markdown]
# ### 5.1 Determinar si un potencial candidato se debería contratar
#
# La idea es transformar la variable respuesta de toda la data mediante el método de **Box-Cox**, para luego tomar el cuantil 75, 50 y 25 y ese valor volver a transformarlo para saber los puntos de corte que la entidad de salud considera para saber si un empleado es o no productivo

# %%
y_transformada, box_cox_lambda_y = stats.boxcox(datos_to_model.request_attend_per_day)

# %%
prob_75=np.quantile(y_transformada,0.75)
prob_50=np.quantile(y_transformada,0.5)
prob_90=np.quantile(y_transformada,0.90)

# %%
valores_quantiles=scipy.special.inv_boxcox(np.asarray([prob_50,prob_75,prob_90]), box_cox_lambda_y)

# %%
valores_quantiles
# Out:
# array([23.26666667, 56.53225649, 81.5       ])
