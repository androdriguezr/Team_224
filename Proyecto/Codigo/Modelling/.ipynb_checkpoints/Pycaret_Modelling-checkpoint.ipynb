# %%
import os
os.chdir('C:\\Users\\USUARIO\\Documents\\GitHub\\Team_224\\Proyecto\\Codigo\\Modelling')

# %%
u=!pip freeze
intalados=str(u)

# %%
to_instalar=['os','pandas','matplotlib','statsmodels','numpy','seaborn','pingouin','pycaret','sklearn','scipy','openpyxl']

# %%
instalados=[x for x in to_instalar if x in  intalados ]
if len(set(to_instalar)-set(instalados))>0:
    # !pip install -r requirements_pycaret.txt
# Out:
# Requirement already satisfied: pandas in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 1)) (1.3.5)
# Collecting scipy<=1.5.4
#   Using cached scipy-1.5.4-cp37-cp37m-win_amd64.whl (31.2 MB)
# Requirement already satisfied: seaborn in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 3)) (0.11.2)
# Requirement already satisfied: matplotlib in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 4)) (3.5.2)
# Requirement already satisfied: IPython in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 5)) (7.34.0)
# Requirement already satisfied: joblib in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 6)) (1.1.0)
# Requirement already satisfied: scikit-learn==0.23.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 7)) (0.23.2)
# Requirement already satisfied: ipywidgets in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 8)) (7.7.1)
# Requirement already satisfied: yellowbrick>=1.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 9)) (1.3.post1)
# Requirement already satisfied: lightgbm>=2.3.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 10)) (3.3.2)
# Requirement already satisfied: plotly>=4.4.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 11)) (5.9.0)
# Requirement already satisfied: wordcloud in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 12)) (1.8.1)
# Requirement already satisfied: textblob in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 13)) (0.17.1)
# Requirement already satisfied: cufflinks>=0.17.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 14)) (0.17.3)
# Requirement already satisfied: umap-learn in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 15)) (0.5.3)
# Requirement already satisfied: pyLDAvis in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 16)) (3.2.2)
# Requirement already satisfied: gensim<4.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 17)) (3.8.3)
# Requirement already satisfied: spacy<2.4.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 18)) (2.3.7)
# Requirement already satisfied: nltk in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 19)) (3.7)
# Requirement already satisfied: mlxtend>=0.17.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 20)) (0.19.0)
# Requirement already satisfied: pyod in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 21)) (1.0.2)
# Requirement already satisfied: pandas-profiling>=2.8.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 22)) (3.2.0)
# Requirement already satisfied: kmodes>=0.10.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 23)) (0.12.1)
# Requirement already satisfied: mlflow in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 24)) (1.26.1)
# Requirement already satisfied: imbalanced-learn==0.7.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 25)) (0.7.0)
# Requirement already satisfied: scikit-plot in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 26)) (0.3.7)
# Requirement already satisfied: Boruta in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 27)) (0.3)
# Requirement already satisfied: pyyaml<6.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 28)) (5.4.1)
# Requirement already satisfied: numba<0.55 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 29)) (0.54.1)
# Requirement already satisfied: pycaret in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 30)) (2.3.10)
# Collecting sklearn
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pingouin
#   Using cached pingouin-0.5.2-py3-none-any.whl
# Requirement already satisfied: statsmodels in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from -r requirements_pycaret.txt (line 33)) (0.13.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from scikit-learn==0.23.2->-r requirements_pycaret.txt (line 7)) (3.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from scikit-learn==0.23.2->-r requirements_pycaret.txt (line 7)) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas->-r requirements_pycaret.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas->-r requirements_pycaret.txt (line 1)) (2022.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from matplotlib->-r requirements_pycaret.txt (line 4)) (4.33.3)
# Requirement already satisfied: traitlets>=4.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (5.3.0)
# Requirement already satisfied: pickleshare in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.7.5)
# Requirement already satisfied: backcall in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.18.1)
# Requirement already satisfied: decorator in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (47.1.0)
# Requirement already satisfied: pygments in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (2.12.0)
# Requirement already satisfied: colorama in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.4.5)
# Requirement already satisfied: matplotlib-inline in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from IPython->-r requirements_pycaret.txt (line 5)) (3.0.29)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipywidgets->-r requirements_pycaret.txt (line 8)) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipywidgets->-r requirements_pycaret.txt (line 8)) (6.15.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipywidgets->-r requirements_pycaret.txt (line 8)) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipywidgets->-r requirements_pycaret.txt (line 8)) (1.1.1)
# Requirement already satisfied: wheel in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from lightgbm>=2.3.1->-r requirements_pycaret.txt (line 10)) (0.37.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from plotly>=4.4.1->-r requirements_pycaret.txt (line 11)) (8.0.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cufflinks>=0.17.0->-r requirements_pycaret.txt (line 14)) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cufflinks>=0.17.0->-r requirements_pycaret.txt (line 14)) (0.3.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from umap-learn->-r requirements_pycaret.txt (line 15)) (0.5.7)
# Requirement already satisfied: tqdm in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from umap-learn->-r requirements_pycaret.txt (line 15)) (4.64.0)
# Requirement already satisfied: jinja2>=2.7.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pyLDAvis->-r requirements_pycaret.txt (line 16)) (3.1.2)
# Requirement already satisfied: numexpr in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pyLDAvis->-r requirements_pycaret.txt (line 16)) (2.8.1)
# Requirement already satisfied: future in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pyLDAvis->-r requirements_pycaret.txt (line 16)) (0.18.2)
# Requirement already satisfied: funcy in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pyLDAvis->-r requirements_pycaret.txt (line 16)) (1.17)
# Requirement already satisfied: Cython==0.29.14 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gensim<4.0.0->-r requirements_pycaret.txt (line 17)) (0.29.14)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gensim<4.0.0->-r requirements_pycaret.txt (line 17)) (6.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (0.9.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (2.28.0)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (7.4.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (0.7.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (3.0.6)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nltk->-r requirements_pycaret.txt (line 19)) (2022.6.2)
# Requirement already satisfied: click in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nltk->-r requirements_pycaret.txt (line 19)) (8.1.3)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.1.12)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (1.9.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.7.4)
# Requirement already satisfied: phik>=0.11.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (1.8)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (2.1.1)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.5.1)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (21.4.0)
# Requirement already satisfied: imagehash in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (4.2.1)
# Requirement already satisfied: waitress in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (2.1.2)
# Requirement already satisfied: docker>=4.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (5.0.3)
# Requirement already satisfied: sqlalchemy in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (1.4.38)
# Requirement already satisfied: prometheus-flask-exporter in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (0.20.2)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (4.21.1)
# Requirement already satisfied: databricks-cli>=0.8.7 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (0.17.0)
# Requirement already satisfied: gitpython>=2.1.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (3.1.27)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (4.11.4)
# Requirement already satisfied: querystring-parser in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (1.2.4)
# Requirement already satisfied: sqlparse>=0.3.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (0.4.2)
# Requirement already satisfied: cloudpickle in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (2.1.0)
# Requirement already satisfied: alembic in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (1.8.0)
# Requirement already satisfied: entrypoints in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (0.4)
# Requirement already satisfied: Flask in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from mlflow->-r requirements_pycaret.txt (line 24)) (2.1.2)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from numba<0.55->-r requirements_pycaret.txt (line 29)) (0.37.0)
# Collecting outdated
#   Using cached outdated-0.2.1-py3-none-any.whl (7.5 kB)
# Collecting pandas-flavor>=0.2.0
#   Using cached pandas_flavor-0.3.0-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: tabulate in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from pingouin->-r requirements_pycaret.txt (line 32)) (0.8.10)
# Collecting pingouin
#   Using cached pingouin-0.5.1-py3-none-any.whl
#   Downloading pingouin-0.5.0.tar.gz (182 kB)
#      -------------------------------------- 182.8/182.8 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading pingouin-0.4.0.tar.gz (206 kB)
#      -------------------------------------- 206.9/206.9 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading pingouin-0.3.12.tar.gz (205 kB)
#      -------------------------------------- 205.1/205.1 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: patsy>=0.5.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from statsmodels->-r requirements_pycaret.txt (line 33)) (0.5.2)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from databricks-cli>=0.8.7->mlflow->-r requirements_pycaret.txt (line 24)) (2.4.0)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from databricks-cli>=0.8.7->mlflow->-r requirements_pycaret.txt (line 24)) (3.2.0)
# Requirement already satisfied: pywin32==227 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from docker>=4.0.0->mlflow->-r requirements_pycaret.txt (line 24)) (227)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from docker>=4.0.0->mlflow->-r requirements_pycaret.txt (line 24)) (1.3.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gitpython>=2.1.0->mlflow->-r requirements_pycaret.txt (line 24)) (4.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gitpython>=2.1.0->mlflow->-r requirements_pycaret.txt (line 24)) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->-r requirements_pycaret.txt (line 24)) (3.8.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.6.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (23.2.0)
# Requirement already satisfied: psutil in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (5.9.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from jedi>=0.16->IPython->-r requirements_pycaret.txt (line 5)) (0.8.3)
# Collecting pandas_flavor>=0.1.2
#   Using cached pandas_flavor-0.2.0-py2.py3-none-any.whl (6.6 kB)
# Collecting xarray
#   Using cached xarray-0.20.2-py3-none-any.whl (845 kB)
# Requirement already satisfied: wcwidth in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->-r requirements_pycaret.txt (line 5)) (0.2.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->-r requirements_pycaret.txt (line 18)) (3.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (6.4.12)
# Requirement already satisfied: importlib-resources in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from alembic->mlflow->-r requirements_pycaret.txt (line 24)) (5.8.0)
# Requirement already satisfied: Mako in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from alembic->mlflow->-r requirements_pycaret.txt (line 24)) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from sqlalchemy->mlflow->-r requirements_pycaret.txt (line 24)) (1.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from Flask->mlflow->-r requirements_pycaret.txt (line 24)) (2.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from Flask->mlflow->-r requirements_pycaret.txt (line 24)) (2.1.2)
# Requirement already satisfied: littleutils in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from outdated->pingouin->-r requirements_pycaret.txt (line 32)) (0.2.2)
# Requirement already satisfied: prometheus-client in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from prometheus-flask-exporter->mlflow->-r requirements_pycaret.txt (line 24)) (0.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->-r requirements_pycaret.txt (line 24)) (5.0.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r requirements_pycaret.txt (line 8)) (4.10.0)
# Requirement already satisfied: nbformat in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (5.4.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.15.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (6.5.0)
# Requirement already satisfied: PyWavelets in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->-r requirements_pycaret.txt (line 22)) (1.3.0)
# Requirement already satisfied: bleach in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (5.0.0)
# Requirement already satisfied: defusedxml in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.7.1)
# Requirement already satisfied: tinycss2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.6.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.2.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (4.6.0)
# Requirement already satisfied: fastjsonschema in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (2.15.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.18.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\usuario\documents\entornos_virtuales\entornoprueba\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->-r requirements_pycaret.txt (line 8)) (2.21)
# Building wheels for collected packages: sklearn, pingouin
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=f1c142d5c1b19973dbafde6bf0ace10288c843199a462febb94ccb697e988ac5
#   Stored in directory: c:\users\usuario\appdata\local\pip\cache\wheels\46\ef\c3\157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
#   Building wheel for pingouin (setup.py): started
#   Building wheel for pingouin (setup.py): finished with status 'done'
#   Created wheel for pingouin: filename=pingouin-0.3.12-py3-none-any.whl size=204285 sha256=ca91668d57a3b9ab00b5a5e07b7d546550d64c54b6cea8ddea98f2731558dc59
#   Stored in directory: c:\users\usuario\appdata\local\pip\cache\wheels\5b\8a\ed\fafe2714a0f047d64fb582105b174b5e5218c82a0d787bbec4
# Successfully built sklearn pingouin
# Installing collected packages: scipy, outdated, xarray, sklearn, pandas_flavor, pingouin
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# Successfully installed outdated-0.2.1 pandas_flavor-0.2.0 pingouin-0.3.12 scipy-1.5.4 sklearn-0.0 xarray-0.20.2

# %%
import pycaret

# %%
#!pip install -r requirements.txt --user
import os
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
import seaborn as sns
from datetime import datetime
import math
import unicodedata
from unicodedata import normalize
import re
from dateutil.relativedelta import relativedelta
import pingouin
import sklearn
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import scipy
from scipy.stats import chi2_contingency
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#import pycaret

# %%
ruta_madre="C:/Users/USUARIO/Documents/GitHub/Team_224/Proyecto"
ruta_insumos=os.path.join(ruta_madre, 'Insumos')
ruta_resultados=os.path.join(ruta_madre, 'Resultados')

# %% [markdown]
# ## 1.0 Importando base de datos preprocesada

# %%
os.chdir(os.path.join(ruta_insumos,'preproccess_data'))
ruta_data_preproc=os.path.join(os.getcwd(),'data_agregada_preproccess.xlsx')
datos_preproc=pd.read_excel(ruta_data_preproc,index_col=0)

# %% [markdown]
# ## 2.0 Featuring engineering
#
# Es empiza a hacer Feature engineering para evitar resultados raros

# %% [markdown]
# ### 2.1 Deflactando los salarios
#
# Debido al gran problema que genera la inflación a lo largo del tiempo, se prefiere usar cifras deflactadas, con lo cual, se utiliza la tabal abstraida del DANE para el IPC anual y se indexa hasta valores correspondientes al 2022. Es decir, la serie se deflacta y se pone todo en las mismas unidades monetarias en el mismo intervalo de tiempo

# %%
inflacion_variacion=pd.read_excel(os.path.join(os.getcwd(),'inflacion.xlsx'),index_col=0)
inflacion_variacion['inflacion']=inflacion_variacion['inflacion']/100+1
inflacion_variacion=inflacion_variacion[inflacion_variacion.index>=datos_preproc.year.min()]

# %%
inflacion_variacion=inflacion_variacion.sort_index(ascending=False).cumprod().reset_index()

# %%
datos_preproc=datos_preproc.merge(inflacion_variacion,on="year",how="left")
datos_preproc.inflacion.fillna(1,inplace=True)

# %%
datos_preproc['wage_deflacted']=datos_preproc['wage_imputed']*datos_preproc['inflacion']

# %% [markdown]
# ### 2.2 Arreglando variables categoricas incompletas

# %%
datos_preproc['total_depedants']=datos_preproc['other_on_charge_person']+datos_preproc['children_amount']

# %%
datos_to_model=datos_preproc[['month','gender','is_special_population','any_disability','MUNICIPIO_DE_RESIDENCIA','home_type',
                             'education_level','PROFESION','marital_status','total_depedants','ESTRATO_SOCIAL','wage_deflacted',
                             'age','years_exp_current_role','request_attend_per_day']]
datos_to_model['total_depedants']=datos_to_model['total_depedants'].astype('str')
datos_to_model['ESTRATO_SOCIAL']=datos_to_model['ESTRATO_SOCIAL'].astype('str')

# %%
datos_to_model.isna().sum()
# Out:
# month                       0
# gender                      3
# is_special_population       3
# any_disability              3
# MUNICIPIO_DE_RESIDENCIA     3
# home_type                   3
# education_level             3
# PROFESION                  65
# marital_status              3
# total_depedants             0
# ESTRATO_SOCIAL              0
# wage_deflacted              0
# age                         3
# years_exp_current_role      3
# request_attend_per_day      0
# dtype: int64

# %% [markdown]
# Note que hay un total importante de NAs en algunos datos. sin embargo, no tenemos ninguna explicación de negocio para reemplazarlos por un numero, por lo que se pondrá como una nueva categoria

# %%
datos_to_model['gender']=datos_to_model['gender'].fillna('OTHER')
datos_to_model['is_special_population']=datos_to_model['is_special_population'].fillna('NO APLICA')
datos_to_model['any_disability']=datos_to_model['any_disability'].fillna('no_reported')
datos_to_model['MUNICIPIO_DE_RESIDENCIA']=datos_to_model['MUNICIPIO_DE_RESIDENCIA'].fillna('NO_REPORTADO')
datos_to_model['home_type']=datos_to_model['home_type'].fillna('OTHER')
datos_to_model['education_level']=datos_to_model['education_level'].fillna('OTHER')
datos_to_model['PROFESION']=datos_to_model['PROFESION'].fillna('OTHER')
datos_to_model['marital_status']=datos_to_model['marital_status'].fillna('OTHER')
datos_to_model['total_depedants']=datos_to_model['total_depedants'].fillna('OTHER')
datos_to_model['ESTRATO_SOCIAL']=datos_to_model['ESTRATO_SOCIAL'].fillna('OTHER')

# %% [markdown]
# El siguiente codigo presenta una transformacion de la variable edad, ya que al verlo respecto a la variable que mide la productividad, tiene una relacion no lineal.

# %% [markdown]
# ### 2.3 Agregadno polinomios de la edad

# %%
datos_to_model['age2']=datos_to_model['age']**2
datos_to_model['age3']=datos_to_model['age']**3
datos_to_model['age4']=datos_to_model['age']**4
datos_to_model['age5']=datos_to_model['age']**5

# %% [markdown]
# ### 2.1 Regresion lineal sin ninguna modificacion

# %% [markdown]
# #### 2.1.1 Dividiendo en test y train set

# %% [markdown]
# Utilzamos un split de 70/30, sin embargo, solo usaremos este ejercicio con fin de tener una referencia de potenciales variables significativas. siendo el peor modelo y luego ir viendo como se comporta a futuro

# %%
y=datos_to_model[datos_to_model.columns[datos_to_model.columns=='request_attend_per_day']]
X=datos_to_model[datos_to_model.columns[datos_to_model.columns!='request_attend_per_day']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# #### 2.1.2 Normalizando y transformando las variables
#
# Normalizaremos salario y años de experiencia y todas las variables de edad

# %%
scaler = StandardScaler()

stand_xtrain=scaler.fit_transform(X_train[['wage_imputed','years_exp_current_role','age','age2','age3','age4','age5']])
X_train[['wage_imputed','years_exp_current_role','age','age2','age3','age4','age5']]=pd.DataFrame(stand_xtrain,columns=['wage_imputed','years_exp_current_role','age','age2','age3','age4','age5'],
                                                                                                 index=X_train.index)

stand_xtest=scaler.fit_transform(X_test[['wage_imputed','years_exp_current_role','age','age2','age3','age4','age5']])
X_test[['wage_imputed','years_exp_current_role','age','age2','age3','age4','age5']]=pd.DataFrame(stand_xtest,columns=['wage_imputed','years_exp_current_role','age','age2','age3','age4','age5'],
                                                                                                index=X_test.index)

# %%
# Out:
#       wage_imputed  years_exp_current_role       age      age2      age3  \
# 0        -1.597724                1.126600  1.052010  0.896079  0.680317
# 1        -1.597724               -0.380445  0.111478 -0.023750 -0.125721
# 2        -1.597724                1.151158  1.052010  0.896079  0.680317
# 3        -1.597724               -0.355887  0.111478 -0.023750 -0.125721
# 4        -1.597724                1.176535  1.052010  0.896079  0.680317
# ...            ...                     ...       ...       ...       ...
# 1678      1.404478               -0.821671 -0.358788 -0.404821 -0.401644
# 1679      1.404478                0.253971 -0.123655 -0.220856 -0.273182
# 1680      1.953639                1.923099  0.346611  0.186497  0.042049
# 1681      1.953639               -0.268297 -1.064186 -0.877876 -0.686137
# 1682      1.404478                0.268706 -0.476354 -0.491877 -0.459159
#
#           age4      age5
# 0     0.453227  0.259047
# 1    -0.182269 -0.199428
# 2     0.453227  0.259047
# 3    -0.182269 -0.199428
# 4     0.453227  0.259047
# ...        ...       ...
# 1678 -0.361535 -0.305721
# 1679 -0.281137 -0.259853
# 1680 -0.062295 -0.121226
# 1681 -0.515599 -0.382125
# 1682 -0.395581 -0.324087
#
# [1683 rows x 7 columns]

# %%
from pycaret.regression import *
s = setup(datos_to_model, target = 'request_attend_per_day')
# Out:
# <style type="text/css">
# #T_a92d7_row3_col1, #T_a92d7_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a92d7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a92d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a92d7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a92d7_row0_col1" class="data row0 col1" >4146</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a92d7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a92d7_row1_col1" class="data row1 col1" >request_attend_per_day</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a92d7_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_a92d7_row2_col1" class="data row2 col1" >(1683, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a92d7_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_a92d7_row3_col1" class="data row3 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a92d7_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_a92d7_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a92d7_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_a92d7_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a92d7_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_a92d7_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a92d7_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_a92d7_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a92d7_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_a92d7_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a92d7_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_a92d7_row9_col1" class="data row9 col1" >(1178, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a92d7_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_a92d7_row10_col1" class="data row10 col1" >(505, 61)</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a92d7_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_a92d7_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a92d7_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_a92d7_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a92d7_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_a92d7_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a92d7_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_a92d7_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a92d7_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_a92d7_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a92d7_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_a92d7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a92d7_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_a92d7_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a92d7_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_a92d7_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a92d7_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_a92d7_row19_col1" class="data row19 col1" >44a8</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a92d7_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_a92d7_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a92d7_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_a92d7_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a92d7_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_a92d7_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a92d7_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_a92d7_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a92d7_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_a92d7_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a92d7_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_a92d7_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a92d7_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_a92d7_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_a92d7_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_a92d7_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_a92d7_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_a92d7_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_a92d7_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_a92d7_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a92d7_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_a92d7_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_a92d7_row30_col1" class="data row30 co

# %%
best=compare_models()
# Out:
# <style type="text/css">
# #T_caea1_ th {
#   text-align: left;
# }
# #T_caea1_row0_col0, #T_caea1_row0_col6, #T_caea1_row1_col0, #T_caea1_row1_col1, #T_caea1_row1_col2, #T_caea1_row1_col3, #T_caea1_row1_col4, #T_caea1_row1_col5, #T_caea1_row1_col6, #T_caea1_row2_col0, #T_caea1_row2_col1, #T_caea1_row2_col2, #T_caea1_row2_col3, #T_caea1_row2_col4, #T_caea1_row2_col5, #T_caea1_row2_col6, #T_caea1_row3_col0, #T_caea1_row3_col1, #T_caea1_row3_col2, #T_caea1_row3_col3, #T_caea1_row3_col4, #T_caea1_row3_col5, #T_caea1_row3_col6, #T_caea1_row4_col0, #T_caea1_row4_col1, #T_caea1_row4_col2, #T_caea1_row4_col3, #T_caea1_row4_col4, #T_caea1_row4_col5, #T_caea1_row5_col0, #T_caea1_row5_col1, #T_caea1_row5_col2, #T_caea1_row5_col3, #T_caea1_row5_col4, #T_caea1_row5_col5, #T_caea1_row5_col6, #T_caea1_row6_col0, #T_caea1_row6_col1, #T_caea1_row6_col2, #T_caea1_row6_col3, #T_caea1_row6_col4, #T_caea1_row6_col5, #T_caea1_row6_col6, #T_caea1_row7_col0, #T_caea1_row7_col1, #T_caea1_row7_col2, #T_caea1_row7_col3, #T_caea1_row7_col4, #T_caea1_row7_col5, #T_caea1_row7_col6, #T_caea1_row8_col0, #T_caea1_row8_col1, #T_caea1_row8_col2, #T_caea1_row8_col3, #T_caea1_row8_col4, #T_caea1_row8_col5, #T_caea1_row8_col6, #T_caea1_row9_col0, #T_caea1_row9_col1, #T_caea1_row9_col2, #T_caea1_row9_col3, #T_caea1_row9_col4, #T_caea1_row9_col5, #T_caea1_row9_col6, #T_caea1_row10_col0, #T_caea1_row10_col1, #T_caea1_row10_col2, #T_caea1_row10_col3, #T_caea1_row10_col4, #T_caea1_row10_col5, #T_caea1_row10_col6, #T_caea1_row11_col0, #T_caea1_row11_col1, #T_caea1_row11_col2, #T_caea1_row11_col3, #T_caea1_row11_col4, #T_caea1_row11_col5, #T_caea1_row11_col6, #T_caea1_row12_col0, #T_caea1_row12_col1, #T_caea1_row12_col2, #T_caea1_row12_col3, #T_caea1_row12_col4, #T_caea1_row12_col5, #T_caea1_row12_col6, #T_caea1_row13_col0, #T_caea1_row13_col1, #T_caea1_row13_col2, #T_caea1_row13_col3, #T_caea1_row13_col4, #T_caea1_row13_col5, #T_caea1_row13_col6, #T_caea1_row14_col0, #T_caea1_row14_col1, #T_caea1_row14_col2, #T_caea1_row14_col3, #T_caea1_row14_col4, #T_caea1_row14_col5, #T_caea1_row14_col6, #T_caea1_row15_col0, #T_caea1_row15_col1, #T_caea1_row15_col2, #T_caea1_row15_col3, #T_caea1_row15_col4, #T_caea1_row15_col5, #T_caea1_row15_col6, #T_caea1_row16_col0, #T_caea1_row16_col1, #T_caea1_row16_col2, #T_caea1_row16_col3, #T_caea1_row16_col4, #T_caea1_row16_col5, #T_caea1_row16_col6, #T_caea1_row17_col0, #T_caea1_row17_col1, #T_caea1_row17_col2, #T_caea1_row17_col3, #T_caea1_row17_col4, #T_caea1_row17_col5, #T_caea1_row17_col6 {
#   text-align: left;
# }
# #T_caea1_row0_col1, #T_caea1_row0_col2, #T_caea1_row0_col3, #T_caea1_row0_col4, #T_caea1_row0_col5, #T_caea1_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_caea1_row0_col7, #T_caea1_row1_col7, #T_caea1_row2_col7, #T_caea1_row3_col7, #T_caea1_row4_col7, #T_caea1_row5_col7, #T_caea1_row6_col7, #T_caea1_row7_col7, #T_caea1_row8_col7, #T_caea1_row9_col7, #T_caea1_row10_col7, #T_caea1_row11_col7, #T_caea1_row12_col7, #T_caea1_row13_col7, #T_caea1_row15_col7, #T_caea1_row16_col7, #T_caea1_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_caea1_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_caea1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_caea1_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_caea1_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_caea1_row0_col1" class="data row0 col1" >9.9619</td>
#       <td id="T_caea1_row0_col2" class="data row0 col2" >277.5623</td>
#       <td id="T_caea1_row0_col3" class="data row0 col3" >16.3857</td>
#       <td id="T_caea1_row0_col4" class="data row0 col4" >0.7686</td>
#       <td id="T_caea1_row0_col5" class="data row0 col5" >0.6124</td>
#       <td id="T_caea1_row0_col6" class="data row0 col6" >2.9479</td>
#       <td id="T_caea1_row0_col7" class="data row0 col7" >0.1190</td>
#     </tr>
#     <tr>
#       <th id="T_caea1_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_caea1_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_caea1_row1_col1" class="data row1 col1" >11.2450</td>
#       <td id="T_caea1_row1_col2" class="data row1 col2" >290.9522</td>
#       <td id="T_caea1_row1_col3" class="data row1 col3" >16.8826</td>
#       <td id="T_caea1_row1_col4" class="data row1 col4" >0.7556</td>
#       <td id="T_caea1_row1_col5" class="data row1 col5" >0.7526</td>
#       <td id="T_caea1_row1_col6" class="data row1 col6" >5.8501</td>
#       <td id="T_caea1_row1_col7" class="data row1 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_caea1_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_caea1_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_caea1_row2_col1" class="data row2 col1" >11.1369</td>
#       <td id="T_caea1_row2_col2" class="data row2 col2" >349.2361</td>
#       <td id="T_caea1_row2_col3" class="data row2 col3" >18.5378</td>
#       <td id="T_caea1_row2_col4" class="data row2 col4" >0.7036</td>
#       <td id="T_caea1_row2_col5" class="data row2 col5" >0.6533</td>
#       <td id="T_caea1_row2_col6" class="data row2 col6" >2.6865</td>
#       <td id="T_caea1_row2_col7" class="data row2 col7" >0.1120</td>
#     </tr>
#     <tr>
#       <th id="T_caea1_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_caea1_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#       <td id="T_caea1_row3_col1" class="data row3 col1" >12.6769</td>
#       <td id="T_caea1_row3_col2" class="data row3 col2" >419.0670</td>
#       <td id="T_caea1_row3_col3" class="data row3 col3" >20.2712</td>
#       <td id="T_caea1_row3_col4" class="data row3 col4" >0.6436</td>
#       <td id="T_caea1_row3_col5" class="data row3 col5" >0.7477</td>
#       <td id="T_caea1_row3_col6" class="data row3 col6" >8.4791</td>
#       <td id="T_caea1_row3_col7" class="data row3 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_caea1_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_caea1_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_caea1_row4_col1" class="data row4 col1" >11.6223</td>
#       <td id="T_caea1_row4_col2" class="data row4 col2" >434.2818</td>
#       <td id="T_caea1_row4_col3" class="data row4 col3" >20.3071</td>
#       <td id="T_caea1_row4_col4" class="data row4 col4" >0.6391</td>
#       <td id="T_caea1_row4_col5" class="data row4 col5" >0.7093</td>
#       <td id="T_caea1_row4_col6" class="data row4 col6" >1.8738</td>
#       <td id="T_caea1_row4_col7" class="data row4 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_caea1_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_caea1_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_caea1_row5_col1" class="data row5 col1" >15.1215</td>
#       <td id="T_caea1_row5_col2" class="data row5 col2" >468.7745</td>
#       <td id="T_caea1_row5_col3" class="data row5 col3" >21.4612</td>
#       <td id="T_caea1_row5_col4" class="data row5 col4" >0.6020</td>
#       <td id="T_caea1_row5_col5" class="data row5 col5" >0.9234</td>
#       <td id="T_caea1_row5_col6" class="data row5 col6" >8.1862</td>
#       <td id="T_caea1_row5_col7" class="data row5 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_caea1_level0_row6" class="row_heading level0 row6" >br</th>
#       <td id="T_caea1_row6_col0" class="data row6 col0" >Bayesian Ridge</td>
#       <td id="T_caea1_row6_col1" class="data row6

# %%
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *
s = setup(data, target = 'charges')
# Out:
# <style type="text/css">
# #T_97e10_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_97e10_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97e10_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97e10_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_97e10_row0_col1" class="data row0 col1" >3750</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97e10_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_97e10_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97e10_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_97e10_row2_col1" class="data row2 col1" >(1338, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97e10_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_97e10_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97e10_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_97e10_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_97e10_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_97e10_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_97e10_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_97e10_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_97e10_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_97e10_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_97e10_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_97e10_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_97e10_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_97e10_row9_col1" class="data row9 col1" >(936, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_97e10_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_97e10_row10_col1" class="data row10 col1" >(402, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_97e10_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_97e10_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_97e10_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_97e10_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_97e10_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_97e10_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_97e10_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_97e10_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_97e10_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_97e10_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_97e10_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_97e10_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_97e10_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_97e10_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_97e10_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_97e10_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_97e10_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_97e10_row19_col1" class="data row19 col1" >6004</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_97e10_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_97e10_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_97e10_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_97e10_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_97e10_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_97e10_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_97e10_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_97e10_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_97e10_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_97e10_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_97e10_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_97e10_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_97e10_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_97e10_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_97e10_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_97e10_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_97e10_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_97e10_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_97e10_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_97e10_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97e10_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_97e10_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_97e10_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_6ef7c_ th {
#   text-align: left;
# }
# #T_6ef7c_row0_col0, #T_6ef7c_row0_col5, #T_6ef7c_row0_col6, #T_6ef7c_row1_col0, #T_6ef7c_row1_col1, #T_6ef7c_row1_col2, #T_6ef7c_row1_col3, #T_6ef7c_row1_col4, #T_6ef7c_row1_col6, #T_6ef7c_row2_col0, #T_6ef7c_row2_col1, #T_6ef7c_row2_col2, #T_6ef7c_row2_col3, #T_6ef7c_row2_col4, #T_6ef7c_row2_col5, #T_6ef7c_row2_col6, #T_6ef7c_row3_col0, #T_6ef7c_row3_col1, #T_6ef7c_row3_col2, #T_6ef7c_row3_col3, #T_6ef7c_row3_col4, #T_6ef7c_row3_col5, #T_6ef7c_row3_col6, #T_6ef7c_row4_col0, #T_6ef7c_row4_col1, #T_6ef7c_row4_col2, #T_6ef7c_row4_col3, #T_6ef7c_row4_col4, #T_6ef7c_row4_col5, #T_6ef7c_row5_col0, #T_6ef7c_row5_col1, #T_6ef7c_row5_col2, #T_6ef7c_row5_col3, #T_6ef7c_row5_col4, #T_6ef7c_row5_col5, #T_6ef7c_row5_col6, #T_6ef7c_row6_col0, #T_6ef7c_row6_col1, #T_6ef7c_row6_col2, #T_6ef7c_row6_col3, #T_6ef7c_row6_col4, #T_6ef7c_row6_col5, #T_6ef7c_row6_col6, #T_6ef7c_row7_col0, #T_6ef7c_row7_col1, #T_6ef7c_row7_col2, #T_6ef7c_row7_col3, #T_6ef7c_row7_col4, #T_6ef7c_row7_col5, #T_6ef7c_row7_col6, #T_6ef7c_row8_col0, #T_6ef7c_row8_col1, #T_6ef7c_row8_col2, #T_6ef7c_row8_col3, #T_6ef7c_row8_col4, #T_6ef7c_row8_col5, #T_6ef7c_row8_col6, #T_6ef7c_row9_col0, #T_6ef7c_row9_col1, #T_6ef7c_row9_col2, #T_6ef7c_row9_col3, #T_6ef7c_row9_col4, #T_6ef7c_row9_col5, #T_6ef7c_row9_col6, #T_6ef7c_row10_col0, #T_6ef7c_row10_col1, #T_6ef7c_row10_col2, #T_6ef7c_row10_col3, #T_6ef7c_row10_col4, #T_6ef7c_row10_col5, #T_6ef7c_row10_col6, #T_6ef7c_row11_col0, #T_6ef7c_row11_col1, #T_6ef7c_row11_col2, #T_6ef7c_row11_col3, #T_6ef7c_row11_col4, #T_6ef7c_row11_col5, #T_6ef7c_row11_col6, #T_6ef7c_row12_col0, #T_6ef7c_row12_col1, #T_6ef7c_row12_col2, #T_6ef7c_row12_col3, #T_6ef7c_row12_col4, #T_6ef7c_row12_col5, #T_6ef7c_row12_col6, #T_6ef7c_row13_col0, #T_6ef7c_row13_col1, #T_6ef7c_row13_col2, #T_6ef7c_row13_col3, #T_6ef7c_row13_col4, #T_6ef7c_row13_col5, #T_6ef7c_row13_col6, #T_6ef7c_row14_col0, #T_6ef7c_row14_col1, #T_6ef7c_row14_col2, #T_6ef7c_row14_col3, #T_6ef7c_row14_col4, #T_6ef7c_row14_col5, #T_6ef7c_row14_col6, #T_6ef7c_row15_col0, #T_6ef7c_row15_col1, #T_6ef7c_row15_col2, #T_6ef7c_row15_col3, #T_6ef7c_row15_col4, #T_6ef7c_row15_col5, #T_6ef7c_row15_col6, #T_6ef7c_row16_col0, #T_6ef7c_row16_col1, #T_6ef7c_row16_col2, #T_6ef7c_row16_col3, #T_6ef7c_row16_col4, #T_6ef7c_row16_col5, #T_6ef7c_row16_col6 {
#   text-align: left;
# }
# #T_6ef7c_row0_col1, #T_6ef7c_row0_col2, #T_6ef7c_row0_col3, #T_6ef7c_row0_col4, #T_6ef7c_row1_col5, #T_6ef7c_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6ef7c_row0_col7, #T_6ef7c_row1_col7, #T_6ef7c_row2_col7, #T_6ef7c_row3_col7, #T_6ef7c_row4_col7, #T_6ef7c_row5_col7, #T_6ef7c_row6_col7, #T_6ef7c_row7_col7, #T_6ef7c_row8_col7, #T_6ef7c_row9_col7, #T_6ef7c_row10_col7, #T_6ef7c_row11_col7, #T_6ef7c_row12_col7, #T_6ef7c_row14_col7, #T_6ef7c_row15_col7, #T_6ef7c_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6ef7c_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6ef7c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ef7c_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_6ef7c_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6ef7c_row0_col1" class="data row0 col1" >2485.4792</td>
#       <td id="T_6ef7c_row0_col2" class="data row0 col2" >21393519.7702</td>
#       <td id="T_6ef7c_row0_col3" class="data row0 col3" >4545.0700</td>
#       <td id="T_6ef7c_row0_col4" class="data row0 col4" >0.8446</td>
#       <td id="T_6ef7c_row0_col5" class="data row0 col5" >0.3882</td>
#       <td id="T_6ef7c_row0_col6" class="data row0 col6" >0.2647</td>
#       <td id="T_6ef7c_row0_col7" class="data row0 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7c_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_6ef7c_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_6ef7c_row1_col1" class="data row1 col1" >2610.6134</td>
#       <td id="T_6ef7c_row1_col2" class="data row1 col2" >22739090.1617</td>
#       <td id="T_6ef7c_row1_col3" class="data row1 col3" >4687.6105</td>
#       <td id="T_6ef7c_row1_col4" class="data row1 col4" >0.8343</td>
#       <td id="T_6ef7c_row1_col5" class="data row1 col5" >0.3871</td>
#       <td id="T_6ef7c_row1_col6" class="data row1 col6" >0.2645</td>
#       <td id="T_6ef7c_row1_col7" class="data row1 col7" >0.0870</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7c_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_6ef7c_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6ef7c_row2_col1" class="data row2 col1" >2835.9005</td>
#       <td id="T_6ef7c_row2_col2" class="data row2 col2" >23961066.8710</td>
#       <td id="T_6ef7c_row2_col3" class="data row2 col3" >4829.2867</td>
#       <td id="T_6ef7c_row2_col4" class="data row2 col4" >0.8256</td>
#       <td id="T_6ef7c_row2_col5" class="data row2 col5" >0.4968</td>
#       <td id="T_6ef7c_row2_col6" class="data row2 col6" >0.3198</td>
#       <td id="T_6ef7c_row2_col7" class="data row2 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7c_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_6ef7c_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_6ef7c_row3_col1" class="data row3 col1" >3750.8889</td>
#       <td id="T_6ef7c_row3_col2" class="data row3 col2" >25505086.0503</td>
#       <td id="T_6ef7c_row3_col3" class="data row3 col3" >5013.0329</td>
#       <td id="T_6ef7c_row3_col4" class="data row3 col4" >0.8174</td>
#       <td id="T_6ef7c_row3_col5" class="data row3 col5" >0.5358</td>
#       <td id="T_6ef7c_row3_col6" class="data row3 col6" >0.5475</td>
#       <td id="T_6ef7c_row3_col7" class="data row3 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7c_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_6ef7c_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_6ef7c_row4_col1" class="data row4 col1" >2610.8542</td>
#       <td id="T_6ef7c_row4_col2" class="data row4 col2" >26527500.9759</td>
#       <td id="T_6ef7c_row4_col3" class="data row4 col3" >5072.4048</td>
#       <td id="T_6ef7c_row4_col4" class="data row4 col4" >0.8060</td>
#       <td id="T_6ef7c_row4_col5" class="data row4 col5" >0.4002</td>
#       <td id="T_6ef7c_row4_col6" class="data row4 col6" >0.2519</td>
#       <td id="T_6ef7c_row4_col7" class="data row4 col7" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7c_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_6ef7c_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_6ef7c_row5_col1" class="data row5 col1" >4228.5423</td>
#       <td id="T_6ef7c_row5_col2" class="data row5 col2" >38645870.6000</td>
#       <td id="T_6ef7c_row5_col3" class="data row5 col3" >6178.6240</td>
#       <td id="T_6ef7c_row5_col4" class="data row5 col4" >0.7264</td>
#       <td id="T_6ef7c_row5_col5" class="data row5 col5" >0.5634</td>
#       <td id="T_6ef7c_row5_col6" class="data row5 col6" >0.4111</td>
#       <td id="T_6ef7c_row5_col7" class="data row5 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_6ef7c_level0_row6" class="row_heading level0 row6" >llar</th>
#       <td id="T_6ef7c_row6_col0" class="data row6 col0" >Lasso Least Angle Regression</td>
#       <td id="T_6ef7c_row6_col1" class="data row6 col1" >4213.0760</td>
#       <td id="T_6ef7c_row6_col2" class="data row6 col2" >38624375.1366</td>

# %%
print(best)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=3750, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# lightgbm    Light Gradient Boosting Machine
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True
